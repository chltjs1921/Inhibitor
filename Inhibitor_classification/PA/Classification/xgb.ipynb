# %%
import numpy as np
import pandas as pd
import xgboost as xgb

from xgboost import XGBClassifier

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from scipy.stats import randint, uniform, loguniform

#데이터 입력
#데이터 입력
df = pd.read_csv('/Users/eunwoo/Inhibitor/PA/csv/PA_inhibitor_descriptor_internal_dataset.csv')
df1 = pd.read_csv('/Users/eunwoo/Inhibitor/PA/csv/PA_inhibitor_descriptor_external_dataset.csv')
df2 = pd.concat([df, df1])

#데이터 분류
dataset = df.values
X = dataset[:,0:-1]
Y = dataset[:,-1]

ex_data =df1.values
exX = ex_data[:,0:-1]
exY = ex_data[:,-1]

tot_data = df2.values
totX = tot_data[:,0:-1]
totY = tot_data[:,-1]

#X 표준화

scaler = StandardScaler()

scaler.fit(X)
X_scaled = scaler.transform(X)
exX_scaled = scaler.transform(exX)
totX_scaled = scaler.transform(totX)

#XGB 분류 실시

xgb = XGBClassifier()
params = {'max_depth': list(range(2,20)),'learning_rate': uniform(1e-5, 0.3),'subsample': uniform(0.1, 1), 
          'min_child_weight': uniform(0.5, 10),'gamma': uniform(0, 1),'n_estimators': list(range(50, 1050))}

xgb_wrapper = RandomizedSearchCV(xgb, params, n_iter = 10, n_jobs=-1, cv=5)

xgbs = xgb_wrapper.fit(X_scaled, Y)

best_params = xgbs.best_params_
print(best_params)

xgbs1 = xgbs.best_estimator_

pred = xgbs1.predict(X_scaled)
accuracy = accuracy_score(Y, pred)
print('xgb 내부 정확도: {0:.4f}'.format(accuracy))
conf_matrix = confusion_matrix(Y, pred)
print(conf_matrix)

expred = xgbs1.predict(exX_scaled)
accuracy = accuracy_score(exY, expred)
print('xgb 외부 정확도: {0:.4f}'.format(accuracy))
ex_conf_matrix = confusion_matrix(exY, expred)
print(ex_conf_matrix)

totpred = xgbs1.predict(totX_scaled)
accuracy = accuracy_score(totY, totpred)
print('xgb 전체 정확도: {0:.4f}'.format(accuracy))
tot_conf_matrix = confusion_matrix(totY, totpred)
print(tot_conf_matrix)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-1f8f3e55c909> in <module>
#      46 xgb_wrapper = RandomizedSearchCV(xgb, params, n_iter = 10000, n_jobs=-1, cv=5)
#      47
# ---> 48 xgbs = xgb_wrapper.fit(X_scaled, Y)
#      49
#      50 best_params = xgbs.best_params_
#
# ~\.conda\envs\Tensorflow\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\.conda\envs\Tensorflow\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     839                 return results
#     840
# --> 841             self._run_search(evaluate_candidates)
#     842
# ...

# %%
import scipy
