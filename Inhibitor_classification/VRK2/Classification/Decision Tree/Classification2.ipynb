# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import graphviz

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, cross_val_score, cross_validate
from sklearn.metrics import accuracy_score, confusion_matrix
from tensorflow.python.keras.utils import np_utils
from sklearn.preprocessing import MinMaxScaler
from sklearn.tree import export_graphviz

#데이터 입력
df = pd.read_csv('./VRK2_inhibitor_descriptor_Internal_dataset_editdt1.csv')

#데이터 분류
dataset = df.values
X = dataset[:,0:-1]#.astype(float)
Y = dataset[:,-1]#.astype(int) 

#X 정규화

scaler = MinMaxScaler()

scaler.fit(X)
X_scaled = scaler.transform(X)

#원-핫 인코딩
Y_encoded = tf.keras.utils.to_categorical(Y)

#데이터셋 분리
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y, test_size=0.2, random_state=10)

#DecisionTree Classifier 생성
dt_clf = DecisionTreeClassifier(min_samples_split=17, min_samples_leaf=1, max_features=2, max_depth=1,
                                max_leaf_nodes=2,random_state=10)

#DecisionTreeClasifer 학습
dt_clf.fit(X_train, Y_train)
pred = dt_clf.predict(X_test)
accuracy = accuracy_score(Y_test, pred)
print('Decision Tree 예측 정확도 : {0:.4f}'.format(accuracy))

#export_graphviz()의 호출 결과로 out_file로 지정된 tree.dot 파일 생성

#export_graphviz(dt_clf,out_file="tree.dot", feature_names=None, class_names=Y_encoded, impurity=True, filled=True)

#위에서 생성한 tree.dot 파일을 Graphviz가 읽어서 주피터 노트북상에서 시각화
#with open("tree.dot") as f:
#    dot_graph = f.read()
#graphviz.Source(dot_graph)    

#최대 정확도 0.8571 표준화, 정규화해도 동일

#cross val 실행
scores = cross_val_score(dt_clf,X_scaled, Y, scoring='accuracy', cv=5)
print('교차 검증별 정확도:' ,np.round(scores,5))
print('평균 검증 정확도:', np.round(np.mean(scores),5))

#confision matrix
pred1 = dt_clf.predict(X_scaled)
conf_matrix = confusion_matrix(Y, pred1)
print(conf_matrix)
# Out:
# Decision Tree 예측 정확도 : 0.8333
# 교차 검증별 정확도: [0.5 0.8 0.8 0.6 0.4]
# 평균 검증 정확도: 0.62
# [[ 0  0  6  0]
#  [ 0  0  2  0]
#  [ 0  0  8  0]
#  [ 0  0  0 10]]
# C:\Users\eunwoo\.conda\envs\Tensorflow\lib\site-packages\sklearn\model_selection\_split.py:670: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import graphviz


from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, cross_val_score, cross_validate
from tensorflow.python.keras.utils import np_utils
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.tree import export_graphviz
from sklearn.metrics import accuracy_score, confusion_matrix

#데이터 입력
df = pd.read_csv('./VRK2_inhibitor_descriptor_Internal_dataset_edit1.csv')

#데이터 분류
dataset = df.values
X = dataset[:,0:-1]#.astype(float)
Y = dataset[:,-1]#.astype(int)

#X 표준화

scaler =StandardScaler()

scaler.fit(X)
X_scaled = scaler.transform(X)

#원-핫 인코딩
Y_encoded = tf.keras.utils.to_categorical(Y)

#데이터셋 분리
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y, test_size=0.2, random_state=10)

#DecisionTree Classifier 생성
dt_clf = DecisionTreeClassifier(random_state=10)
dt_clf.fit(X_scaled, Y)

# DecisionTreeClassifier의 하이퍼 파리미터 추출
#print('\nDecisionTreeClassifier 기본 하이퍼파라미터:\n', dt_clf.get_params())

#파라미터 튜닝
parameters = {'min_samples_split':list(range(2,20)), 
              'min_samples_leaf': list(range(1,10)), 
              'max_features': list(range(2,4)), 
              'max_depth': list(range(1,6)), 
              'max_leaf_nodes': list(range(2,10))}
grid_dclf = GridSearchCV(dt_clf, param_grid=parameters, scoring='accuracy', cv=5, verbose=1)
grid_dclf.fit(X_train, Y_train)

print('Decision Tree 최적 하이퍼 파라미터 :',grid_dclf.best_params_)
print('Decision Tree 최고 정확도 : {0:.4f}'.format(grid_dclf.best_score_))
best_dclf = grid_dclf.best_estimator_

#DecisionTreeClasifer 학습

best_dclf.fit(X_train, Y_train)
pred = best_dclf.predict(X_scaled)
accuracy = accuracy_score(Y, pred)

print('Decision Tree 예측 정확도 : {0:.4f}'.format(accuracy))

#export_graphviz()의 호출 결과로 out_file로 지정된 tree.dot 파일 생성

#export_graphviz(best_dclf,out_file="tree.dot", feature_names=None, class_names=Y_encoded, impurity=True, filled=True)

#위에서 생성한 tree.dot 파일을 Graphviz가 읽어서 주피터 노트북상에서 시각화
#with open("tree.dot") as f:
#    dot_graph = f.read()
#graphviz.Source(dot_graph)    

#cross val 실행
scores = cross_val_score(best_dclf,X_scaled, Y, scoring='accuracy', cv=5)
print('교차 검증별 정확도:' ,np.round(scores,5))
print('평균 검증 정확도:', np.round(np.mean(scores),5))

#confusion matrix 실행
conf_matrix = confusion_matrix(Y, pred)
print(conf_matrix)

#외부 데이터세트로 실행
ex = pd.read_csv('./VRK2_inhibitor_descriptor_external_dataset_edit1.csv')

datasetex = ex.values
exX = dataset[:,0:-1]#.astype(float)
exY = dataset[:,-1]#.astype(int)

#X 표준화

scaler =StandardScaler()

scaler.fit(exX)
exX_scaled = scaler.transform(X)

expred = best_dclf.predict(exX_scaled)
accuracy = accuracy_score(exY, expred)

print('Decision Tree 외부세트 예측 정확도 : {0:.4f}'.format(accuracy))

#confusion matrix 실행
#ex_conf_matrix = confusion_matrix(exY, expred)
#print(ex_conf_matrix)
# Out:
# Fitting 5 folds for each of 12960 candidates, totalling 64800 fits
# C:\Users\eunwoo\.conda\envs\Tensorflow\lib\site-packages\sklearn\model_selection\_split.py:670: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 64800 out of 64800 | elapsed:  3.1min finished
# Decision Tree 최적 하이퍼 파라미터 : {'max_depth': 2, 'max_features': 3, 'max_leaf_nodes': 3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Decision Tree 최고 정확도 : 0.8500
# Decision Tree 예측 정확도 : 0.9231
# 교차 검증별 정확도: [0.83333 1.      1.      0.8     0.4    ]
# 평균 검증 정확도: 0.80667
# [[ 6  0  0  0]
#  [ 2  0  0  0]
#  [ 0  0  8  0]
#  [ 0  0  0 10]]
# Decision Tree 외부세트 예측 정확도 : 0.9231
# [3. 3. 3. 3. 3. 3. 3. 3. 3. 3. 2. 2. 2. 2. 2. 2. 2. 2. 1. 1. 0. 0. 0. 0.
#  0. 0.]
# [3. 3. 3. 3. 3. 3. 3. 3. 3. 3. 2. 2. 2. 2. 2. 2. 2. 2. 0. 0. 0. 0. 0. 0.
#  0. 0.]
# C:\Users\eunwoo\.conda\envs\Tensorflow\lib\site-packages\sklearn\model_selection\_split.py:670: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import graphviz
import matplotlib.pyplot as plt


from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from tensorflow.python.keras.utils import np_utils
from sklearn.preprocessing import MinMaxScaler
from sklearn.tree import export_graphviz
from sklearn.inspection import permutation_importance

#데이터 입력
df = pd.read_csv('./VRK2_inhibitor_descriptor_Internal_dataset_dropunmane.csv')

#데이터 분류
dataset = df.values
X = dataset[:,0:3336]#.astype(float)
Y = dataset[:,3337]

#X 정규화

scaler = MinMaxScaler()

scaler.fit(X)
X_scaled = scaler.transform(X)

#원-핫 인코딩
Y_encoded = tf.keras.utils.to_categorical(Y)

#데이터셋 분리
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y_encoded, test_size=0.2, random_state=10)

#DecisionTree Classifier 생성
dt_clf = DecisionTreeClassifier(max_depth=3, max_features=4, max_leaf_nodes=5, min_samples_leaf=2, 
                                min_samples_split=6, random_state=10)

#DecisionTreeClasifer 학습
dt_clf.fit(X_train, Y_train)

pred = dt_clf.predict(X_test)
accuracy = accuracy_score(Y_test, pred)
print('Decision Tree 예측 정확도 : {0:.4f}'.format(accuracy))

#최대 정확도 0.8571 표준화, 정규화해도 동일

#f1 = f1_score(Y_test,dt_clf,average='macro')
#print(f1)

importance = dt_clf.feature_importances_
a = pd.Series(importance)
a.to_csv('./decisiontree_importance.csv')
# summarize feature importance
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.8f' % (i,v))
# plot feature importance
#plt.bar([x for x in range(len(importance))], importance)
#plt.axis([3000, 3335, 0, 0.4])
#plt.show()
# Out:
# Decision Tree 예측 정확도 : 0.1667
# Feature: 0, Score: 0.00000000
# Feature: 1, Score: 0.00000000
# Feature: 2, Score: 0.00000000
# Feature: 3, Score: 0.00000000
# Feature: 4, Score: 0.00000000
# Feature: 5, Score: 0.00000000
# Feature: 6, Score: 0.00000000
# Feature: 7, Score: 0.00000000
# Feature: 8, Score: 0.00000000
# Feature: 9, Score: 0.00000000
# Feature: 10, Score: 0.00000000
# Feature: 11, Score: 0.00000000
# Feature: 12, Score: 0.00000000
# Feature: 13, Score: 0.00000000
# Feature: 14, Score: 0.00000000
# Feature: 15, Score: 0.00000000
# Feature: 16, Score: 0.00000000
# Feature: 17, Score: 0.00000000
# Feature: 18, Score: 0.00000000
# Feature: 19, Score: 0.00000000
# Feature: 20, Score: 0.00000000
# Feature: 21, Score: 0.00000000
# Feature: 22, Score: 0.00000000
# Feature: 23, Score: 0.00000000
# Feature: 24, Score: 0.00000000
# Feature: 25, Score: 0.00000000
# Feature: 26, Score: 0.00000000
# Feature: 27, Score: 0.00000000
# Feature: 28, Score: 0.00000000
# Feature: 29, Score: 0.00000000
# Feature: 30, Score: 0.00000000
# Feature: 31, Score: 0.00000000
# Feature: 32, Score: 0.00000000
# Feature: 33, Score: 0.00000000
# Feature: 34, Score: 0.00000000
# Feature: 35, Score: 0.00000000
# Feature: 36, Score: 0.00000000
# Feature: 37, Score: 0.00000000
# Feature: 38, Score: 0.00000000
# Feature: 39, Score: 0.00000000
# Feature: 40, Score: 0.00000000
# Feature: 41, Score: 0.00000000
# Feature: 42, Score: 0.00000000
# Feature: 43, Score: 0.00000000
# Feature: 44, Score: 0.00000000
# Feature: 45, Score: 0.00000000
# Feature: 46, Score: 0.00000000
# Feature: 47, Score: 0.00000000
# Feature: 48, Score: 0.00000000
# Feature: 49, Score: 0.00000000
# Feature: 50, Score: 0.00000000
# Feature: 51, Score: 0.00000000
# Feature: 52, Score: 0.00000000
# Feature: 53, Score: 0.00000000
# Feature: 54, Score: 0.00000000
# Feature: 55, Score: 0.00000000
# Feature: 56, Score: 0.00000000
# Feature: 57, Score: 0.00000000
# Feature: 58, Score: 0.00000000
# Feature: 59, Score: 0.00000000
# Feature: 60, Score: 0.00000000
# Feature: 61, Score: 0.00000000
# Feature: 62, Score: 0.00000000
# Feature: 63, Score: 0.00000000
# Feature: 64, Score: 0.00000000
# Feature: 65, Score: 0.00000000
# Feature: 66, Score: 0.00000000
# Feature: 67, Score: 0.00000000
# Feature: 68, Score: 0.00000000
# Feature: 69, Score: 0.00000000
# Feature: 70, Score: 0.00000000
# Feature: 71, Score: 0.00000000
# Feature: 72, Score: 0.00000000
# Feature: 73, Score: 0.00000000
# Feature: 74, Score: 0.00000000
# Feature: 75, Score: 0.00000000
# Feature: 76, Score: 0.00000000
# Feature: 77, Score: 0.00000000
# Feature: 78, Score: 0.00000000
# Feature: 79, Score: 0.00000000
# Feature: 80, Score: 0.00000000
# Feature: 81, Score: 0.00000000
# Feature: 82, Score: 0.00000000
# Feature: 83, Score: 0.00000000
# Feature: 84, Score: 0.00000000
# Feature: 85, Score: 0.00000000
# Feature: 86, Score: 0.00000000
# Feature: 87, Score: 0.00000000
# Feature: 88, Score: 0.00000000
# Feature: 89, Score: 0.00000000
# Feature: 90, Score: 0.00000000
# Feature: 91, Score: 0.00000000
# Feature: 92, Score: 0.00000000
# Feature: 93, Score: 0.00000000
# Feature: 94, Score: 0.00000000
# Feature: 95, Score: 0.00000000
# Feature: 96, Score: 0.00000000
# Feature: 97, Score: 0.00000000
# Feature: 98, Score: 0.00000000
# Feature: 99, Score: 0.00000000
# Feature: 100, Score: 0.00000000
# Feature: 101, Score: 0.00000000
# Feature: 102, Score: 0.00000000
# Feature: 103, Score: 0.00000000
# Feature: 104, Score: 0.00000000
# Feature: 105, Score: 0.00000000
# Feature: 106, Score: 0.00000000
# Feature: 107, Score: 0.00000000
# Feature: 108, Score: 0.00000000
# Feature: 109, Score: 0.00000000
# Feature: 110, Score: 0.00000000
# Feature: 111, Score: 0.00000000
# Feature: 112, Score: 0.00000000
# Feature: 113, Score: 0.00000000
# Feature: 114, Score: 0.00000000
# Feature: 115, Score: 0.00000000
# Feature: 116, Score: 0.00000000
# Feature: 117, Score: 0.00000000
# Feature: 118, Score: 0.00000000
# Feature: 119, Score: 0.00000000
# Feature: 120, Score: 0.00000000
# Feature: 121, Score: 0.00000000
# Feature: 122, Score: 0.00000000
# Feature: 123, Score: 0.00000000
# Feature: 124, Score: 0.00000000
# Feature: 125, Score: 0.00000000
# Feature: 126, Score: 0.00000000
# Feature: 127, Score: 0.00000000
# Feature: 128, Score: 0.00000000
# Feature: 129, Score: 0.00000000
# Feature: 130, Score: 0.00000000
# Feature: 131, Score: 0.00000000
# Feature: 132, Score: 0.00000000
# Feature: 133, Score: 0.00000000
# Feature: 134, Score: 0.00000000
# Feature: 135, Score: 0.00000000
# Feature: 136, Score: 0.00000000
# Feature: 137, Score: 0.00000000
# Feature: 138, Score: 0.00000000
# Feature: 139, Score: 0.00000000
# Feature: 140, Score: 0.00000000
# Feature: 141, Score: 0.00000000
# Feature: 142, Score: 0.00000000
# Feature: 143, Score: 0.00000000
# Feature: 144, Score: 0.00000000
# Feature: 145, Score: 0.00000000
# Feature: 146, Score: 0.00000000
# Feature: 147, Score: 0.00000000
# Feature: 148, Score: 0.00000000
# Feature: 149, Score: 0.00000000
# Feature: 150, Score: 0.00000000
# Feature: 151, Score: 0.00000000
# Feature: 152, Score: 0.00000000
# Feature: 153, Score: 0.00000000
# Feature: 154, Score: 0.00000000
# Feature: 155, Score: 0.00000000
# Feature: 156, Score: 0.00000000
# Feature: 157, Score: 0.00000000
# Feature: 158, Score: 0.00000000
# Feature: 159, Score: 0.00000000
# Feature: 160, Score: 0.00000000
# Feature: 161, Score: 0.00000000
# Feature: 162, Score: 0.00000000
# Feature: 163, Score: 0.00000000
# Feature: 164, Score: 0.00000000
# Feature: 165, Score: 0.00000000
# Feature: 166, Score: 0.00000000
# Feature: 167, Score: 0.00000000
# Feature: 168, Score: 0.00000000
# Feature: 169, Score: 0.00000000
# Feature: 170, Score: 0.00000000
# Feature: 171, Score: 0.00000000
# Feature: 172, Score: 0.00000000
# Feature: 173, Score: 0.00000000
# Feature: 174, Score: 0.00000000
# Feature: 175, Score: 0.00000000
# Feature: 176, Score: 0.00000000
# Feature: 177, Score: 0.00000000
# Feature: 178, Score: 0.00000000
# Feature: 179, Score: 0.00000000
# Feature: 180, Score: 0.00000000
# Feature: 181, Score: 0.00000000
# Feature: 182, Score: 0.00000000
# Feature: 183, Score: 0.00000000
# Feature: 184, Score: 0.00000000
# Feature: 185, Score: 0.00000000
# Feature: 186, Score: 0.00000000
# Feature: 187, Score: 0.00000000
# Feature: 188, Score: 0.00000000
# Feature: 189, Score: 0.00000000
# Feature: 190, Score: 0.00000000
# Feature: 191, Score: 0.00000000
# Feature: 192, Score: 0.00000000
# Feature: 193, Score: 0.00000000
# Feature: 194, Score: 0.00000000
# Feature: 195, Score: 0.00000000
# Feature: 196, Score: 0.00000000
# Feature: 197, Score: 0.00000000
# Feature: 198, Score: 0.00000000
# Feature: 199, Score: 0.00000000
# Feature: 200, Score: 0.00000000
# Feature: 201, Score: 0.00000000
# Feature: 202, Score: 0.00000000
# Feature: 203, Score: 0.00000000
# Feature: 204, Score: 0.00000000
# Feature: 205, Score: 0.00000000
# Feature: 206, Score: 0.00000000
# Feature: 207, Score: 0.00000000
# Feature: 208, Score: 0.00000000
# Feature: 209, Score: 0.00000000
# Feature: 210, Score: 0.00000000
# Feature: 211, Score: 0.00000000
# Feature: 212, Score: 0.00000000
# Feature: 213, Score: 0.00000000
# Feature: 214, Score: 0.00000000
# Feature: 215, Score: 0.00000000
# Feature: 216, Score: 0.00000000
# Feature: 217, Score: 0.00000000
# Feature: 218, Score: 0.00000000
# Feature: 219, Score: 0.00000000
# Feature: 220, Score: 0.00000000
# Feature: 221, Score: 0.00000000
# Feature: 222, Score: 0.00000000
# Feature: 223, Score: 0.00000000
# Feature: 224, Score: 0.00000000
# Feature: 225, Score: 0.00000000
# Feature: 226, Score: 0.00000000
# Feature: 227, Score: 0.00000000
# Feature: 228, Score: 0.00000000
# Feature: 229, Score: 0.00000000
# Feature: 230, Score: 0.00000000
# Feature: 231, Score: 0.00000000
# Feature: 232, Score: 0.00000000
# Feature: 233, Score: 0.00000000
# Feature: 234, Score: 0.00000000
# Feature: 235, Score: 0.00000000
# Feature: 236, Score: 0.00000000
# Feature: 237, Score: 0.00000000
# Feature: 238, Score: 0.00000000
# Feature: 239, Score: 0.00000000
# Feature: 240, Score: 0.00000000
# Feature: 241, Score: 0.00000000
# Feature: 242, Score: 0.00000000
# Feature: 243, Score: 0.00000000
# Feature: 244, Score: 0.00000000
# Feature: 245, Score: 0.00000000
# Feature: 246, Score: 0.00000000
# Feature: 247, Score: 0.00000000
# Feature: 248, Score: 0.00000000
# Feature: 249, Score: 0.00000000
# Feature: 250, Score: 0.00000000
# Feature: 251, Score: 0.00000000
# Feature: 252, Score: 0.00000000
# Feature: 253, Score: 0.00000000
# Feature: 254, Score: 0.00000000
# Feature: 255, Score: 0.00000000
# Feature: 256, Score: 0.00000000
# Feature: 257, Score: 0.00000000
# Feature: 258, Score: 0.00000000
# Feature: 259, Score: 0.00000000
# Feature: 260, Score: 0.00000000
# Feature: 261, Score: 0.00000000
# Feature: 262, Score: 0.00000000
# Feature: 263, Score: 0.00000000
# Feature: 264, Score: 0.00000000
# Feature: 265, Score: 0.00000000
# Feature: 266, Score: 0.00000000
# Feature: 267, Score: 0.00000000
# Feature: 268, Score: 0.00000000
# Feature: 269, Score: 0.00000000
# Feature: 270, Score: 0.00000000
# Feature: 271, Score: 0.00000000
# Feature: 272, Score: 0.00000000
# Feature: 273, Score: 0.00000000
# Feature: 274, Score: 0.00000000
# Feature: 275, Score: 0.00000000
# Feature: 276, Score: 0.00000000
# Feature: 277, Score: 0.00000000
# Feature: 278, Score: 0.00000000
# Feature: 279, Score: 0.00000000
# Feature: 280, Score: 0.00000000
# Feature: 281, Score: 0.00000000
# Feature: 282, Score: 0.00000000
# Feature: 283, Score: 0.00000000
# Feature: 284, Score: 0.00000000
# Feature: 285, Score: 0.00000000
# Feature: 286, Score: 0.00000000
# Feature: 287, Score: 0.00000000
# Feature: 288, Score: 0.00000000
# Feature: 289, Score: 0.00000000
# Feature: 290, Score: 0.00000000
# Feature: 291, Score: 0.00000000
# Feature: 292, Score: 0.00000000
# Feature: 293, Score: 0.00000000
# Feature: 294, Score: 0.00000000
# Feature: 295, Score: 0.00000000
# Feature: 296, Score: 0.00000000
# Feature: 297, Score: 0.00000000
# Feature: 298, Score: 0.00000000
# Feature: 299, Score: 0.00000000
# Feature: 300, Score: 0.00000000
# Feature: 301, Score: 0.00000000
# Feature: 302, Score: 0.00000000
# Feature: 303, Score: 0.00000000
# Feature: 304, Score: 0.00000000
# Feature: 305, Score: 0.00000000
# Feature: 306, Score: 0.00000000
# Feature: 307, Score: 0.00000000
# Feature: 308, Score: 0.00000000
# Feature: 309, Score: 0.00000000
# Feature: 310, Score: 0.00000000
# Feature: 311, Score: 0.00000000
# Feature: 312, Score: 0.00000000
# Feature: 313, Score: 0.00000000
# Feature: 314, Score: 0.00000000
# Feature: 315, Score: 0.00000000
# Feature: 316, Score: 0.00000000
# Feature: 317, Score: 0.00000000
# Feature: 318, Score: 0.00000000
# Feature: 319, Score: 0.00000000
# Feature: 320, Score: 0.00000000
# Feature: 321, Score: 0.00000000
# Feature: 322, Score: 0.00000000
# Feature: 323, Score: 0.00000000
# Feature: 324, Score: 0.00000000
# Feature: 325, Score: 0.00000000
# Feature: 326, Score: 0.00000000
# Feature: 327, Score: 0.00000000
# Feature: 328, Score: 0.00000000
# Feature: 329, Score: 0.00000000
# Feature: 330, Score: 0.00000000
# Feature: 331, Score: 0.00000000
# Feature: 332, Score: 0.00000000
# Feature: 333, Score: 0.00000000
# Feature: 334, Score: 0.00000000
# Feature: 335, Score: 0.00000000
# Feature: 336, Score: 0.00000000
# Feature: 337, Score: 0.00000000
# Feature: 338, Score: 0.00000000
# Feature: 339, Score: 0.00000000
# Feature: 340, Score: 0.00000000
# Feature: 341, Score: 0.00000000
# Feature: 342, Score: 0.00000000
# Feature: 343, Score: 0.00000000
# Feature: 344, Score: 0.00000000
# Feature: 345, Score: 0.00000000
# Feature: 346, Score: 0.00000000
# Feature: 347, Score: 0.00000000
# Feature: 348, Score: 0.00000000
# Feature: 349, Score: 0.00000000
# Feature: 350, Score: 0.00000000
# Feature: 351, Score: 0.00000000
# Feature: 352, Score: 0.00000000
# Feature: 353, Score: 0.00000000
# Feature: 354, Score: 0.00000000
# Feature: 355, Score: 0.00000000
# Feature: 356, Score: 0.00000000
# Feature: 357, Score: 0.00000000
# Feature: 358, Score: 0.00000000
# Feature: 359, Score: 0.00000000
# Feature: 360, Score: 0.00000000
# Feature: 361, Score: 0.00000000
# Feature: 362, Score: 0.00000000
# Feature: 363, Score: 0.00000000
# Feature: 364, Score: 0.00000000
# Feature: 365, Score: 0.00000000
# Feature: 366, Score: 0.00000000
# Feature: 367, Score: 0.00000000
# Feature: 368, Score: 0.00000000
# Feature: 369, Score: 0.00000000
# Feature: 370, Score: 0.00000000
# Feature: 371, Score: 0.00000000
# Feature: 372, Score: 0.00000000
# Feature: 373, Score: 0.00000000
# Feature: 374, Score: 0.00000000
# Feature: 375, Score: 0.00000000
# Feature: 376, Score: 0.00000000
# Feature: 377, Score: 0.00000000
# Feature: 378, Score: 0.00000000
# Feature: 379, Score: 0.00000000
# Feature: 380, Score: 0.00000000
# Feature: 381, Score: 0.00000000
# Feature: 382, Score: 0.00000000
# Feature: 383, Score: 0.00000000
# Feature: 384, Score: 0.00000000
# Feature: 385, Score: 0.00000000
# Feature: 386, Score: 0.00000000
# Feature: 387, Score: 0.00000000
# Feature: 388, Score: 0.00000000
# Feature: 389, Score: 0.00000000
# Feature: 390, Score: 0.00000000
# Feature: 391, Score: 0.00000000
# Feature: 392, Score: 0.00000000
# Feature: 393, Score: 0.00000000
# Feature: 394, Score: 0.00000000
# Feature: 395, Score: 0.00000000
# Feature: 396, Score: 0.00000000
# Feature: 397, Score: 0.00000000
# Feature: 398, Score: 0.00000000
# Feature: 399, Score: 0.00000000
# Feature: 400, Score: 0.00000000
# Feature: 401, Score: 0.00000000
# Feature: 402, Score: 0.00000000
# Feature: 403, Score: 0.00000000
# Feature: 404, Score: 0.00000000
# Feature: 405, Score: 0.00000000
# Feature: 406, Score: 0.00000000
# Feature: 407, Score: 0.00000000
# Feature: 408, Score: 0.00000000
# Feature: 409, Score: 0.00000000
# Feature: 410, Score: 0.00000000
# Feature: 411, Score: 0.00000000
# Feature: 412, Score: 0.00000000
# Feature: 413, Score: 0.00000000
# Feature: 414, Score: 0.00000000
# Feature: 415, Score: 0.00000000
# Feature: 416, Score: 0.00000000
# Feature: 417, Score: 0.00000000
# Feature: 418, Score: 0.00000000
# Feature: 419, Score: 0.00000000
# Feature: 420, Score: 0.00000000
# Feature: 421, Score: 0.00000000
# Feature: 422, Score: 0.00000000
# Feature: 423, Score: 0.00000000
# Feature: 424, Score: 0.00000000
# Feature: 425, Score: 0.00000000
# Feature: 426, Score: 0.00000000
# Feature: 427, Score: 0.00000000
# Feature: 428, Score: 0.00000000
# Feature: 429, Score: 0.00000000
# Feature: 430, Score: 0.00000000
# Feature: 431, Score: 0.00000000
# Feature: 432, Score: 0.00000000
# Feature: 433, Score: 0.00000000
# Feature: 434, Score: 0.00000000
# Feature: 435, Score: 0.00000000
# Feature: 436, Score: 0.00000000
# Feature: 437, Score: 0.00000000
# Feature: 438, Score: 0.00000000
# Feature: 439, Score: 0.00000000
# Feature: 440, Score: 0.00000000
# Feature: 441, Score: 0.00000000
# Feature: 442, Score: 0.00000000
# Feature: 443, Score: 0.00000000
# Feature: 444, Score: 0.00000000
# Feature: 445, Score: 0.00000000
# Feature: 446, Score: 0.00000000
# Feature: 447, Score: 0.00000000
# Feature: 448, Score: 0.00000000
# Feature: 449, Score: 0.00000000
# Feature: 450, Score: 0.00000000
# Feature: 451, Score: 0.00000000
# Feature: 452, Score: 0.00000000
# Feature: 453, Score: 0.00000000
# Feature: 454, Score: 0.00000000
# Feature: 455, Score: 0.00000000
# Feature: 456, Score: 0.00000000
# Feature: 457, Score: 0.00000000
# Feature: 458, Score: 0.00000000
# Feature: 459, Score: 0.00000000
# Feature: 460, Score: 0.00000000
# Feature: 461, Score: 0.00000000
# Feature: 462, Score: 0.00000000
# Feature: 463, Score: 0.00000000
# Feature: 464, Score: 0.00000000
# Feature: 465, Score: 0.00000000
# Feature: 466, Score: 0.00000000
# Feature: 467, Score: 0.00000000
# Feature: 468, Score: 0.00000000
# Feature: 469, Score: 0.00000000
# Feature: 470, Score: 0.00000000
# Feature: 471, Score: 0.00000000
# Feature: 472, Score: 0.00000000
# Feature: 473, Score: 0.00000000
# Feature: 474, Score: 0.00000000
# Feature: 475, Score: 0.00000000
# Feature: 476, Score: 0.00000000
# Feature: 477, Score: 0.00000000
# Feature: 478, Score: 0.00000000
# Feature: 479, Score: 0.00000000
# Feature: 480, Score: 0.00000000
# Feature: 481, Score: 0.00000000
# Feature: 482, Score: 0.00000000
# Feature: 483, Score: 0.00000000
# Feature: 484, Score: 0.00000000
# Feature: 485, Score: 0.00000000
# Feature: 486, Score: 0.00000000
# Feature: 487, Score: 0.00000000
# Feature: 488, Score: 0.00000000
# Feature: 489, Score: 0.00000000
# Feature: 490, Score: 0.00000000
# Feature: 491, Score: 0.00000000
# Feature: 492, Score: 0.00000000
# Feature: 493, Score: 0.00000000
# Feature: 494, Score: 0.00000000
# Feature: 495, Score: 0.00000000
# Feature: 496, Score: 0.00000000
# Feature: 497, Score: 0.00000000
# Feature: 498, Score: 0.00000000
# Feature: 499, Score: 0.00000000
# Feature: 500, Score: 0.00000000
# Feature: 501, Score: 0.00000000
# Feature: 502, Score: 0.00000000
# Feature: 503, Score: 0.00000000
# Feature: 504, Score: 0.00000000
# Feature: 505, Score: 0.00000000
# Feature: 506, Score: 0.00000000
# Feature: 507, Score: 0.00000000
# Feature: 508, Score: 0.00000000
# Feature: 509, Score: 0.00000000
# Feature: 510, Score: 0.00000000
# Feature: 511, Score: 0.00000000
# Feature: 512, Score: 0.00000000
# Feature: 513, Score: 0.00000000
# Feature: 514, Score: 0.00000000
# Feature: 515, Score: 0.00000000
# Feature: 516, Score: 0.00000000
# Feature: 517, Score: 0.00000000
# Feature: 518, Score: 0.00000000
# Feature: 519, Score: 0.00000000
# Feature: 520, Score: 0.00000000
# Feature: 521, Score: 0.00000000
# Feature: 522, Score: 0.00000000
# Feature: 523, Score: 0.00000000
# Feature: 524, Score: 0.00000000
# Feature: 525, Score: 0.00000000
# Feature: 526, Score: 0.00000000
# Feature: 527, Score: 0.00000000
# Feature: 528, Score: 0.00000000
# Feature: 529, Score: 0.00000000
# Feature: 530, Score: 0.00000000
# Feature: 531, Score: 0.00000000
# Feature: 532, Score: 0.00000000
# Feature: 533, Score: 0.00000000
# Feature: 534, Score: 0.00000000
# Feature: 535, Score: 0.00000000
# Feature: 536, Score: 0.00000000
# Feature: 537, Score: 0.00000000
# Feature: 538, Score: 0.00000000
# Feature: 539, Score: 0.00000000
# Feature: 540, Score: 0.00000000
# Feature: 541, Score: 0.00000000
# Feature: 542, Score: 0.00000000
# Feature: 543, Score: 0.00000000
# Feature: 544, Score: 0.00000000
# Feature: 545, Score: 0.00000000
# Feature: 546, Score: 0.00000000
# Feature: 547, Score: 0.00000000
# Feature: 548, Score: 0.00000000
# Feature: 549, Score: 0.00000000
# Feature: 550, Score: 0.00000000
# Feature: 551, Score: 0.00000000
# Feature: 552, Score: 0.00000000
# Feature: 553, Score: 0.00000000
# Feature: 554, Score: 0.00000000
# Feature: 555, Score: 0.00000000
# Feature: 556, Score: 0.00000000
# Feature: 557, Score: 0.00000000
# Feature: 558, Score: 0.00000000
# Feature: 559, Score: 0.00000000
# Feature: 560, Score: 0.00000000
# Feature: 561, Score: 0.00000000
# Feature: 562, Score: 0.00000000
# Feature: 563, Score: 0.00000000
# Feature: 564, Score: 0.00000000
# Feature: 565, Score: 0.00000000
# Feature: 566, Score: 0.00000000
# Feature: 567, Score: 0.00000000
# Feature: 568, Score: 0.00000000
# Feature: 569, Score: 0.00000000
# Feature: 570, Score: 0.00000000
# Feature: 571, Score: 0.00000000
# Feature: 572, Score: 0.00000000
# Feature: 573, Score: 0.00000000
# Feature: 574, Score: 0.00000000
# Feature: 575, Score: 0.00000000
# Feature: 576, Score: 0.00000000
# Feature: 577, Score: 0.00000000
# Feature: 578, Score: 0.00000000
# Feature: 579, Score: 0.00000000
# Feature: 580, Score: 0.00000000
# Feature: 581, Score: 0.00000000
# Feature: 582, Score: 0.00000000
# Feature: 583, Score: 0.00000000
# Feature: 584, Score: 0.00000000
# Feature: 585, Score: 0.00000000
# Feature: 586, Score: 0.00000000
# Feature: 587, Score: 0.00000000
# Feature: 588, Score: 0.00000000
# Feature: 589, Score: 0.00000000
# Feature: 590, Score: 0.00000000
# Feature: 591, Score: 0.00000000
# Feature: 592, Score: 0.00000000
# Feature: 593, Score: 0.00000000
# Feature: 594, Score: 0.00000000
# Feature: 595, Score: 0.00000000
# Feature: 596, Score: 0.00000000
# Feature: 597, Score: 0.00000000
# Feature: 598, Score: 0.00000000
# Feature: 599, Score: 0.00000000
# Feature: 600, Score: 0.00000000
# Feature: 601, Score: 0.00000000
# Feature: 602, Score: 0.00000000
# Feature: 603, Score: 0.00000000
# Feature: 604, Score: 0.00000000
# Feature: 605, Score: 0.00000000
# Feature: 606, Score: 0.00000000
# Feature: 607, Score: 0.00000000
# Feature: 608, Score: 0.00000000
# Feature: 609, Score: 0.00000000
# Feature: 610, Score: 0.00000000
# Feature: 611, Score: 0.00000000
# Feature: 612, Score: 0.00000000
# Feature: 613, Score: 0.00000000
# Feature: 614, Score: 0.00000000
# Feature: 615, Score: 0.00000000
# Feature: 616, Score: 0.00000000
# Feature: 617, Score: 0.00000000
# Feature: 618, Score: 0.00000000
# Feature: 619, Score: 0.00000000
# Feature: 620, Score: 0.00000000
# Feature: 621, Score: 0.00000000
# Feature: 622, Score: 0.00000000
# Feature: 623, Score: 0.00000000
# Feature: 624, Score: 0.00000000
# Feature: 625, Score: 0.00000000
# Feature: 626, Score: 0.00000000
# Feature: 627, Score: 0.00000000
# Feature: 628, Score: 0.00000000
# Feature: 629, Score: 0.00000000
# Feature: 630, Score: 0.00000000
# Feature: 631, Score: 0.00000000
# Feature: 632, Score: 0.00000000
# Feature: 633, Score: 0.00000000
# Feature: 634, Score: 0.00000000
# Feature: 635, Score: 0.00000000
# Feature: 636, Score: 0.00000000
# Feature: 637, Score: 0.00000000
# Feature: 638, Score: 0.00000000
# Feature: 639, Score: 0.00000000
# Feature: 640, Score: 0.00000000
# Feature: 641, Score: 0.00000000
# Feature: 642, Score: 0.00000000
# Feature: 643, Score: 0.00000000
# Feature: 644, Score: 0.00000000
# Feature: 645, Score: 0.00000000
# Feature: 646, Score: 0.00000000
# Feature: 647, Score: 0.00000000
# Feature: 648, Score: 0.00000000
# Feature: 649, Score: 0.00000000
# Feature: 650, Score: 0.00000000
# Feature: 651, Score: 0.00000000
# Feature: 652, Score: 0.00000000
# Feature: 653, Score: 0.00000000
# Feature: 654, Score: 0.00000000
# Feature: 655, Score: 0.00000000
# Feature: 656, Score: 0.00000000
# Feature: 657, Score: 0.05952381
# Feature: 658, Score: 0.00000000
# Feature: 659, Score: 0.00000000
# Feature: 660, Score: 0.00000000
# Feature: 661, Score: 0.00000000
# Feature: 662, Score: 0.00000000
# Feature: 663, Score: 0.00000000
# Feature: 664, Score: 0.00000000
# Feature: 665, Score: 0.00000000
# Feature: 666, Score: 0.00000000
# Feature: 667, Score: 0.00000000
# Feature: 668, Score: 0.00000000
# Feature: 669, Score: 0.00000000
# Feature: 670, Score: 0.00000000
# Feature: 671, Score: 0.00000000
# Feature: 672, Score: 0.00000000
# Feature: 673, Score: 0.00000000
# Feature: 674, Score: 0.00000000
# Feature: 675, Score: 0.00000000
# Feature: 676, Score: 0.00000000
# Feature: 677, Score: 0.00000000
# Feature: 678, Score: 0.00000000
# Feature: 679, Score: 0.00000000
# Feature: 680, Score: 0.00000000
# Feature: 681, Score: 0.00000000
# Feature: 682, Score: 0.00000000
# Feature: 683, Score: 0.00000000
# Feature: 684, Score: 0.00000000
# Feature: 685, Score: 0.00000000
# Feature: 686, Score: 0.00000000
# Feature: 687, Score: 0.00000000
# Feature: 688, Score: 0.00000000
# Feature: 689, Score: 0.00000000
# Feature: 690, Score: 0.00000000
# Feature: 691, Score: 0.00000000
# Feature: 692, Score: 0.00000000
# Feature: 693, Score: 0.00000000
# Feature: 694, Score: 0.00000000
# Feature: 695, Score: 0.00000000
# Feature: 696, Score: 0.00000000
# Feature: 697, Score: 0.00000000
# Feature: 698, Score: 0.00000000
# Feature: 699, Score: 0.00000000
# Feature: 700, Score: 0.00000000
# Feature: 701, Score: 0.00000000
# Feature: 702, Score: 0.00000000
# Feature: 703, Score: 0.00000000
# Feature: 704, Score: 0.00000000
# Feature: 705, Score: 0.00000000
# Feature: 706, Score: 0.00000000
# Feature: 707, Score: 0.00000000
# Feature: 708, Score: 0.00000000
# Feature: 709, Score: 0.00000000
# Feature: 710, Score: 0.00000000
# Feature: 711, Score: 0.00000000
# Feature: 712, Score: 0.00000000
# Feature: 713, Score: 0.00000000
# Feature: 714, Score: 0.00000000
# Feature: 715, Score: 0.00000000
# Feature: 716, Score: 0.00000000
# Feature: 717, Score: 0.00000000
# Feature: 718, Score: 0.00000000
# Feature: 719, Score: 0.00000000
# Feature: 720, Score: 0.00000000
# Feature: 721, Score: 0.00000000
# Feature: 722, Score: 0.00000000
# Feature: 723, Score: 0.00000000
# Feature: 724, Score: 0.00000000
# Feature: 725, Score: 0.00000000
# Feature: 726, Score: 0.00000000
# Feature: 727, Score: 0.00000000
# Feature: 728, Score: 0.00000000
# Feature: 729, Score: 0.00000000
# Feature: 730, Score: 0.00000000
# Feature: 731, Score: 0.00000000
# Feature: 732, Score: 0.00000000
# Feature: 733, Score: 0.00000000
# Feature: 734, Score: 0.00000000
# Feature: 735, Score: 0.00000000
# Feature: 736, Score: 0.00000000
# Feature: 737, Score: 0.00000000
# Feature: 738, Score: 0.00000000
# Feature: 739, Score: 0.00000000
# Feature: 740, Score: 0.00000000
# Feature: 741, Score: 0.00000000
# Feature: 742, Score: 0.00000000
# Feature: 743, Score: 0.00000000
# Feature: 744, Score: 0.00000000
# Feature: 745, Score: 0.00000000
# Feature: 746, Score: 0.00000000
# Feature: 747, Score: 0.00000000
# Feature: 748, Score: 0.00000000
# Feature: 749, Score: 0.00000000
# Feature: 750, Score: 0.00000000
# Feature: 751, Score: 0.00000000
# Feature: 752, Score: 0.00000000
# Feature: 753, Score: 0.00000000
# Feature: 754, Score: 0.00000000
# Feature: 755, Score: 0.00000000
# Feature: 756, Score: 0.00000000
# Feature: 757, Score: 0.00000000
# Feature: 758, Score: 0.00000000
# Feature: 759, Score: 0.00000000
# Feature: 760, Score: 0.00000000
# Feature: 761, Score: 0.00000000
# Feature: 762, Score: 0.00000000
# Feature: 763, Score: 0.00000000
# Feature: 764, Score: 0.00000000
# Feature: 765, Score: 0.00000000
# Feature: 766, Score: 0.00000000
# Feature: 767, Score: 0.00000000
# Feature: 768, Score: 0.00000000
# Feature: 769, Score: 0.00000000
# Feature: 770, Score: 0.00000000
# Feature: 771, Score: 0.00000000
# Feature: 772, Score: 0.00000000
# Feature: 773, Score: 0.00000000
# Feature: 774, Score: 0.00000000
# Feature: 775, Score: 0.00000000
# Feature: 776, Score: 0.00000000
# Feature: 777, Score: 0.00000000
# Feature: 778, Score: 0.00000000
# Feature: 779, Score: 0.00000000
# Feature: 780, Score: 0.00000000
# Feature: 781, Score: 0.00000000
# Feature: 782, Score: 0.00000000
# Feature: 783, Score: 0.00000000
# Feature: 784, Score: 0.00000000
# Feature: 785, Score: 0.00000000
# Feature: 786, Score: 0.00000000
# Feature: 787, Score: 0.00000000
# Feature: 788, Score: 0.00000000
# Feature: 789, Score: 0.00000000
# Feature: 790, Score: 0.00000000
# Feature: 791, Score: 0.00000000
# Feature: 792, Score: 0.00000000
# Feature: 793, Score: 0.00000000
# Feature: 794, Score: 0.00000000
# Feature: 795, Score: 0.00000000
# Feature: 796, Score: 0.00000000
# Feature: 797, Score: 0.00000000
# Feature: 798, Score: 0.00000000
# Feature: 799, Score: 0.00000000
# Feature: 800, Score: 0.00000000
# Feature: 801, Score: 0.00000000
# Feature: 802, Score: 0.00000000
# Feature: 803, Score: 0.00000000
# Feature: 804, Score: 0.00000000
# Feature: 805, Score: 0.00000000
# Feature: 806, Score: 0.00000000
# Feature: 807, Score: 0.00000000
# Feature: 808, Score: 0.00000000
# Feature: 809, Score: 0.00000000
# Feature: 810, Score: 0.00000000
# Feature: 811, Score: 0.00000000
# Feature: 812, Score: 0.00000000
# Feature: 813, Score: 0.00000000
# Feature: 814, Score: 0.00000000
# Feature: 815, Score: 0.00000000
# Feature: 816, Score: 0.00000000
# Feature: 817, Score: 0.00000000
# Feature: 818, Score: 0.00000000
# Feature: 819, Score: 0.00000000
# Feature: 820, Score: 0.00000000
# Feature: 821, Score: 0.00000000
# Feature: 822, Score: 0.00000000
# Feature: 823, Score: 0.00000000
# Feature: 824, Score: 0.00000000
# Feature: 825, Score: 0.00000000
# Feature: 826, Score: 0.00000000
# Feature: 827, Score: 0.00000000
# Feature: 828, Score: 0.00000000
# Feature: 829, Score: 0.00000000
# Feature: 830, Score: 0.00000000
# Feature: 831, Score: 0.00000000
# Feature: 832, Score: 0.00000000
# Feature: 833, Score: 0.00000000
# Feature: 834, Score: 0.00000000
# Feature: 835, Score: 0.00000000
# Feature: 836, Score: 0.00000000
# Feature: 837, Score: 0.00000000
# Feature: 838, Score: 0.00000000
# Feature: 839, Score: 0.00000000
# Feature: 840, Score: 0.00000000
# Feature: 841, Score: 0.00000000
# Feature: 842, Score: 0.00000000
# Feature: 843, Score: 0.00000000
# Feature: 844, Score: 0.00000000
# Feature: 845, Score: 0.00000000
# Feature: 846, Score: 0.00000000
# Feature: 847, Score: 0.00000000
# Feature: 848, Score: 0.00000000
# Feature: 849, Score: 0.00000000
# Feature: 850, Score: 0.00000000
# Feature: 851, Score: 0.00000000
# Feature: 852, Score: 0.00000000
# Feature: 853, Score: 0.00000000
# Feature: 854, Score: 0.00000000
# Feature: 855, Score: 0.00000000
# Feature: 856, Score: 0.00000000
# Feature: 857, Score: 0.00000000
# Feature: 858, Score: 0.00000000
# Feature: 859, Score: 0.00000000
# Feature: 860, Score: 0.00000000
# Feature: 861, Score: 0.00000000
# Feature: 862, Score: 0.00000000
# Feature: 863, Score: 0.00000000
# Feature: 864, Score: 0.00000000
# Feature: 865, Score: 0.00000000
# Feature: 866, Score: 0.00000000
# Feature: 867, Score: 0.00000000
# Feature: 868, Score: 0.00000000
# Feature: 869, Score: 0.00000000
# Feature: 870, Score: 0.00000000
# Feature: 871, Score: 0.00000000
# Feature: 872, Score: 0.00000000
# Feature: 873, Score: 0.00000000
# Feature: 874, Score: 0.00000000
# Feature: 875, Score: 0.00000000
# Feature: 876, Score: 0.00000000
# Feature: 877, Score: 0.00000000
# Feature: 878, Score: 0.00000000
# Feature: 879, Score: 0.00000000
# Feature: 880, Score: 0.00000000
# Feature: 881, Score: 0.00000000
# Feature: 882, Score: 0.00000000
# Feature: 883, Score: 0.00000000
# Feature: 884, Score: 0.00000000
# Feature: 885, Score: 0.00000000
# Feature: 886, Score: 0.00000000
# Feature: 887, Score: 0.00000000
# Feature: 888, Score: 0.00000000
# Feature: 889, Score: 0.00000000
# Feature: 890, Score: 0.00000000
# Feature: 891, Score: 0.00000000
# Feature: 892, Score: 0.00000000
# Feature: 893, Score: 0.00000000
# Feature: 894, Score: 0.00000000
# Feature: 895, Score: 0.00000000
# Feature: 896, Score: 0.00000000
# Feature: 897, Score: 0.00000000
# Feature: 898, Score: 0.00000000
# Feature: 899, Score: 0.00000000
# Feature: 900, Score: 0.00000000
# Feature: 901, Score: 0.00000000
# Feature: 902, Score: 0.00000000
# Feature: 903, Score: 0.00000000
# Feature: 904, Score: 0.00000000
# Feature: 905, Score: 0.00000000
# Feature: 906, Score: 0.00000000
# Feature: 907, Score: 0.00000000
# Feature: 908, Score: 0.00000000
# Feature: 909, Score: 0.00000000
# Feature: 910, Score: 0.00000000
# Feature: 911, Score: 0.00000000
# Feature: 912, Score: 0.00000000
# Feature: 913, Score: 0.00000000
# Feature: 914, Score: 0.00000000
# Feature: 915, Score: 0.00000000
# Feature: 916, Score: 0.00000000
# Feature: 917, Score: 0.00000000
# Feature: 918, Score: 0.00000000
# Feature: 919, Score: 0.00000000
# Feature: 920, Score: 0.00000000
# Feature: 921, Score: 0.00000000
# Feature: 922, Score: 0.00000000
# Feature: 923, Score: 0.00000000
# Feature: 924, Score: 0.00000000
# Feature: 925, Score: 0.00000000
# Feature: 926, Score: 0.00000000
# Feature: 927, Score: 0.00000000
# Feature: 928, Score: 0.00000000
# Feature: 929, Score: 0.00000000
# Feature: 930, Score: 0.00000000
# Feature: 931, Score: 0.00000000
# Feature: 932, Score: 0.00000000
# Feature: 933, Score: 0.00000000
# Feature: 934, Score: 0.00000000
# Feature: 935, Score: 0.00000000
# Feature: 936, Score: 0.00000000
# Feature: 937, Score: 0.00000000
# Feature: 938, Score: 0.00000000
# Feature: 939, Score: 0.00000000
# Feature: 940, Score: 0.00000000
# Feature: 941, Score: 0.00000000
# Feature: 942, Score: 0.00000000
# Feature: 943, Score: 0.00000000
# Feature: 944, Score: 0.00000000
# Feature: 945, Score: 0.00000000
# Feature: 946, Score: 0.00000000
# Feature: 947, Score: 0.00000000
# Feature: 948, Score: 0.00000000
# Feature: 949, Score: 0.00000000
# Feature: 950, Score: 0.00000000
# Feature: 951, Score: 0.00000000
# Feature: 952, Score: 0.00000000
# Feature: 953, Score: 0.00000000
# Feature: 954, Score: 0.00000000
# Feature: 955, Score: 0.00000000
# Feature: 956, Score: 0.00000000
# Feature: 957, Score: 0.00000000
# Feature: 958, Score: 0.00000000
# Feature: 959, Score: 0.00000000
# Feature: 960, Score: 0.00000000
# Feature: 961, Score: 0.00000000
# Feature: 962, Score: 0.00000000
# Feature: 963, Score: 0.00000000
# Feature: 964, Score: 0.00000000
# Feature: 965, Score: 0.00000000
# Feature: 966, Score: 0.00000000
# Feature: 967, Score: 0.00000000
# Feature: 968, Score: 0.00000000
# Feature: 969, Score: 0.00000000
# Feature: 970, Score: 0.00000000
# Feature: 971, Score: 0.00000000
# Feature: 972, Score: 0.00000000
# Feature: 973, Score: 0.00000000
# Feature: 974, Score: 0.00000000
# Feature: 975, Score: 0.00000000
# Feature: 976, Score: 0.00000000
# Feature: 977, Score: 0.00000000
# Feature: 978, Score: 0.00000000
# Feature: 979, Score: 0.00000000
# Feature: 980, Score: 0.00000000
# Feature: 981, Score: 0.00000000
# Feature: 982, Score: 0.00000000
# Feature: 983, Score: 0.00000000
# Feature: 984, Score: 0.00000000
# Feature: 985, Score: 0.00000000
# Feature: 986, Score: 0.00000000
# Feature: 987, Score: 0.00000000
# Feature: 988, Score: 0.00000000
# Feature: 989, Score: 0.00000000
# Feature: 990, Score: 0.00000000
# Feature: 991, Score: 0.00000000
# Feature: 992, Score: 0.00000000
# Feature: 993, Score: 0.00000000
# Feature: 994, Score: 0.00000000
# Feature: 995, Score: 0.00000000
# Feature: 996, Score: 0.00000000
# Feature: 997, Score: 0.00000000
# Feature: 998, Score: 0.00000000
# Feature: 999, Score: 0.00000000
# Feature: 1000, Score: 0.00000000
# Feature: 1001, Score: 0.00000000
# Feature: 1002, Score: 0.00000000
# Feature: 1003, Score: 0.00000000
# Feature: 1004, Score: 0.00000000
# Feature: 1005, Score: 0.00000000
# Feature: 1006, Score: 0.00000000
# Feature: 1007, Score: 0.00000000
# Feature: 1008, Score: 0.00000000
# Feature: 1009, Score: 0.00000000
# Feature: 1010, Score: 0.00000000
# Feature: 1011, Score: 0.00000000
# Feature: 1012, Score: 0.00000000
# Feature: 1013, Score: 0.00000000
# Feature: 1014, Score: 0.00000000
# Feature: 1015, Score: 0.00000000
# Feature: 1016, Score: 0.00000000
# Feature: 1017, Score: 0.00000000
# Feature: 1018, Score: 0.00000000
# Feature: 1019, Score: 0.00000000
# Feature: 1020, Score: 0.00000000
# Feature: 1021, Score: 0.00000000
# Feature: 1022, Score: 0.00000000
# Feature: 1023, Score: 0.00000000
# Feature: 1024, Score: 0.00000000
# Feature: 1025, Score: 0.00000000
# Feature: 1026, Score: 0.00000000
# Feature: 1027, Score: 0.00000000
# Feature: 1028, Score: 0.00000000
# Feature: 1029, Score: 0.00000000
# Feature: 1030, Score: 0.00000000
# Feature: 1031, Score: 0.00000000
# Feature: 1032, Score: 0.00000000
# Feature: 1033, Score: 0.00000000
# Feature: 1034, Score: 0.00000000
# Feature: 1035, Score: 0.00000000
# Feature: 1036, Score: 0.00000000
# Feature: 1037, Score: 0.00000000
# Feature: 1038, Score: 0.00000000
# Feature: 1039, Score: 0.00000000
# Feature: 1040, Score: 0.00000000
# Feature: 1041, Score: 0.00000000
# Feature: 1042, Score: 0.00000000
# Feature: 1043, Score: 0.00000000
# Feature: 1044, Score: 0.00000000
# Feature: 1045, Score: 0.00000000
# Feature: 1046, Score: 0.00000000
# Feature: 1047, Score: 0.00000000
# Feature: 1048, Score: 0.00000000
# Feature: 1049, Score: 0.00000000
# Feature: 1050, Score: 0.00000000
# Feature: 1051, Score: 0.00000000
# Feature: 1052, Score: 0.00000000
# Feature: 1053, Score: 0.00000000
# Feature: 1054, Score: 0.00000000
# Feature: 1055, Score: 0.00000000
# Feature: 1056, Score: 0.00000000
# Feature: 1057, Score: 0.00000000
# Feature: 1058, Score: 0.00000000
# Feature: 1059, Score: 0.00000000
# Feature: 1060, Score: 0.00000000
# Feature: 1061, Score: 0.00000000
# Feature: 1062, Score: 0.00000000
# Feature: 1063, Score: 0.00000000
# Feature: 1064, Score: 0.00000000
# Feature: 1065, Score: 0.00000000
# Feature: 1066, Score: 0.00000000
# Feature: 1067, Score: 0.00000000
# Feature: 1068, Score: 0.00000000
# Feature: 1069, Score: 0.00000000
# Feature: 1070, Score: 0.00000000
# Feature: 1071, Score: 0.00000000
# Feature: 1072, Score: 0.00000000
# Feature: 1073, Score: 0.00000000
# Feature: 1074, Score: 0.00000000
# Feature: 1075, Score: 0.00000000
# Feature: 1076, Score: 0.00000000
# Feature: 1077, Score: 0.00000000
# Feature: 1078, Score: 0.00000000
# Feature: 1079, Score: 0.00000000
# Feature: 1080, Score: 0.00000000
# Feature: 1081, Score: 0.00000000
# Feature: 1082, Score: 0.00000000
# Feature: 1083, Score: 0.00000000
# Feature: 1084, Score: 0.00000000
# Feature: 1085, Score: 0.00000000
# Feature: 1086, Score: 0.00000000
# Feature: 1087, Score: 0.00000000
# Feature: 1088, Score: 0.00000000
# Feature: 1089, Score: 0.00000000
# Feature: 1090, Score: 0.00000000
# Feature: 1091, Score: 0.00000000
# Feature: 1092, Score: 0.00000000
# Feature: 1093, Score: 0.00000000
# Feature: 1094, Score: 0.00000000
# Feature: 1095, Score: 0.00000000
# Feature: 1096, Score: 0.00000000
# Feature: 1097, Score: 0.00000000
# Feature: 1098, Score: 0.00000000
# Feature: 1099, Score: 0.00000000
# Feature: 1100, Score: 0.00000000
# Feature: 1101, Score: 0.00000000
# Feature: 1102, Score: 0.00000000
# Feature: 1103, Score: 0.00000000
# Feature: 1104, Score: 0.00000000
# Feature: 1105, Score: 0.00000000
# Feature: 1106, Score: 0.00000000
# Feature: 1107, Score: 0.00000000
# Feature: 1108, Score: 0.00000000
# Feature: 1109, Score: 0.00000000
# Feature: 1110, Score: 0.00000000
# Feature: 1111, Score: 0.00000000
# Feature: 1112, Score: 0.00000000
# Feature: 1113, Score: 0.00000000
# Feature: 1114, Score: 0.00000000
# Feature: 1115, Score: 0.00000000
# Feature: 1116, Score: 0.00000000
# Feature: 1117, Score: 0.00000000
# Feature: 1118, Score: 0.00000000
# Feature: 1119, Score: 0.00000000
# Feature: 1120, Score: 0.00000000
# Feature: 1121, Score: 0.00000000
# Feature: 1122, Score: 0.00000000
# Feature: 1123, Score: 0.00000000
# Feature: 1124, Score: 0.00000000
# Feature: 1125, Score: 0.00000000
# Feature: 1126, Score: 0.00000000
# Feature: 1127, Score: 0.00000000
# Feature: 1128, Score: 0.00000000
# Feature: 1129, Score: 0.00000000
# Feature: 1130, Score: 0.00000000
# Feature: 1131, Score: 0.00000000
# Feature: 1132, Score: 0.00000000
# Feature: 1133, Score: 0.00000000
# Feature: 1134, Score: 0.00000000
# Feature: 1135, Score: 0.00000000
# Feature: 1136, Score: 0.00000000
# Feature: 1137, Score: 0.00000000
# Feature: 1138, Score: 0.00000000
# Feature: 1139, Score: 0.00000000
# Feature: 1140, Score: 0.00000000
# Feature: 1141, Score: 0.00000000
# Feature: 1142, Score: 0.00000000
# Feature: 1143, Score: 0.00000000
# Feature: 1144, Score: 0.00000000
# Feature: 1145, Score: 0.00000000
# Feature: 1146, Score: 0.00000000
# Feature: 1147, Score: 0.32142857
# Feature: 1148, Score: 0.00000000
# Feature: 1149, Score: 0.00000000
# Feature: 1150, Score: 0.00000000
# Feature: 1151, Score: 0.00000000
# Feature: 1152, Score: 0.00000000
# Feature: 1153, Score: 0.00000000
# Feature: 1154, Score: 0.00000000
# Feature: 1155, Score: 0.00000000
# Feature: 1156, Score: 0.00000000
# Feature: 1157, Score: 0.00000000
# Feature: 1158, Score: 0.00000000
# Feature: 1159, Score: 0.00000000
# Feature: 1160, Score: 0.00000000
# Feature: 1161, Score: 0.00000000
# Feature: 1162, Score: 0.00000000
# Feature: 1163, Score: 0.00000000
# Feature: 1164, Score: 0.00000000
# Feature: 1165, Score: 0.00000000
# Feature: 1166, Score: 0.00000000
# Feature: 1167, Score: 0.00000000
# Feature: 1168, Score: 0.00000000
# Feature: 1169, Score: 0.00000000
# Feature: 1170, Score: 0.00000000
# Feature: 1171, Score: 0.00000000
# Feature: 1172, Score: 0.00000000
# Feature: 1173, Score: 0.00000000
# Feature: 1174, Score: 0.00000000
# Feature: 1175, Score: 0.00000000
# Feature: 1176, Score: 0.00000000
# Feature: 1177, Score: 0.00000000
# Feature: 1178, Score: 0.00000000
# Feature: 1179, Score: 0.00000000
# Feature: 1180, Score: 0.00000000
# Feature: 1181, Score: 0.00000000
# Feature: 1182, Score: 0.00000000
# Feature: 1183, Score: 0.00000000
# Feature: 1184, Score: 0.00000000
# Feature: 1185, Score: 0.00000000
# Feature: 1186, Score: 0.00000000
# Feature: 1187, Score: 0.00000000
# Feature: 1188, Score: 0.00000000
# Feature: 1189, Score: 0.00000000
# Feature: 1190, Score: 0.00000000
# Feature: 1191, Score: 0.00000000
# Feature: 1192, Score: 0.00000000
# Feature: 1193, Score: 0.00000000
# Feature: 1194, Score: 0.00000000
# Feature: 1195, Score: 0.00000000
# Feature: 1196, Score: 0.00000000
# Feature: 1197, Score: 0.00000000
# Feature: 1198, Score: 0.00000000
# Feature: 1199, Score: 0.00000000
# Feature: 1200, Score: 0.00000000
# Feature: 1201, Score: 0.00000000
# Feature: 1202, Score: 0.00000000
# Feature: 1203, Score: 0.00000000
# Feature: 1204, Score: 0.00000000
# Feature: 1205, Score: 0.00000000
# Feature: 1206, Score: 0.00000000
# Feature: 1207, Score: 0.00000000
# Feature: 1208, Score: 0.00000000
# Feature: 1209, Score: 0.00000000
# Feature: 1210, Score: 0.00000000
# Feature: 1211, Score: 0.00000000
# Feature: 1212, Score: 0.00000000
# Feature: 1213, Score: 0.00000000
# Feature: 1214, Score: 0.00000000
# Feature: 1215, Score: 0.00000000
# Feature: 1216, Score: 0.00000000
# Feature: 1217, Score: 0.00000000
# Feature: 1218, Score: 0.00000000
# Feature: 1219, Score: 0.00000000
# Feature: 1220, Score: 0.00000000
# Feature: 1221, Score: 0.00000000
# Feature: 1222, Score: 0.00000000
# Feature: 1223, Score: 0.00000000
# Feature: 1224, Score: 0.00000000
# Feature: 1225, Score: 0.00000000
# Feature: 1226, Score: 0.00000000
# Feature: 1227, Score: 0.00000000
# Feature: 1228, Score: 0.00000000
# Feature: 1229, Score: 0.00000000
# Feature: 1230, Score: 0.00000000
# Feature: 1231, Score: 0.00000000
# Feature: 1232, Score: 0.00000000
# Feature: 1233, Score: 0.00000000
# Feature: 1234, Score: 0.00000000
# Feature: 1235, Score: 0.00000000
# Feature: 1236, Score: 0.00000000
# Feature: 1237, Score: 0.00000000
# Feature: 1238, Score: 0.00000000
# Feature: 1239, Score: 0.00000000
# Feature: 1240, Score: 0.00000000
# Feature: 1241, Score: 0.00000000
# Feature: 1242, Score: 0.00000000
# Feature: 1243, Score: 0.00000000
# Feature: 1244, Score: 0.00000000
# Feature: 1245, Score: 0.00000000
# Feature: 1246, Score: 0.00000000
# Feature: 1247, Score: 0.00000000
# Feature: 1248, Score: 0.00000000
# Feature: 1249, Score: 0.00000000
# Feature: 1250, Score: 0.00000000
# Feature: 1251, Score: 0.00000000
# Feature: 1252, Score: 0.00000000
# Feature: 1253, Score: 0.00000000
# Feature: 1254, Score: 0.00000000
# Feature: 1255, Score: 0.00000000
# Feature: 1256, Score: 0.00000000
# Feature: 1257, Score: 0.00000000
# Feature: 1258, Score: 0.00000000
# Feature: 1259, Score: 0.00000000
# Feature: 1260, Score: 0.00000000
# Feature: 1261, Score: 0.00000000
# Feature: 1262, Score: 0.00000000
# Feature: 1263, Score: 0.00000000
# Feature: 1264, Score: 0.00000000
# Feature: 1265, Score: 0.00000000
# Feature: 1266, Score: 0.00000000
# Feature: 1267, Score: 0.00000000
# Feature: 1268, Score: 0.00000000
# Feature: 1269, Score: 0.00000000
# Feature: 1270, Score: 0.00000000
# Feature: 1271, Score: 0.00000000
# Feature: 1272, Score: 0.00000000
# Feature: 1273, Score: 0.00000000
# Feature: 1274, Score: 0.00000000
# Feature: 1275, Score: 0.00000000
# Feature: 1276, Score: 0.00000000
# Feature: 1277, Score: 0.00000000
# Feature: 1278, Score: 0.00000000
# Feature: 1279, Score: 0.00000000
# Feature: 1280, Score: 0.00000000
# Feature: 1281, Score: 0.00000000
# Feature: 1282, Score: 0.00000000
# Feature: 1283, Score: 0.00000000
# Feature: 1284, Score: 0.00000000
# Feature: 1285, Score: 0.00000000
# Feature: 1286, Score: 0.00000000
# Feature: 1287, Score: 0.00000000
# Feature: 1288, Score: 0.00000000
# Feature: 1289, Score: 0.00000000
# Feature: 1290, Score: 0.00000000
# Feature: 1291, Score: 0.00000000
# Feature: 1292, Score: 0.00000000
# Feature: 1293, Score: 0.00000000
# Feature: 1294, Score: 0.00000000
# Feature: 1295, Score: 0.00000000
# Feature: 1296, Score: 0.00000000
# Feature: 1297, Score: 0.00000000
# Feature: 1298, Score: 0.00000000
# Feature: 1299, Score: 0.00000000
# Feature: 1300, Score: 0.00000000
# Feature: 1301, Score: 0.00000000
# Feature: 1302, Score: 0.00000000
# Feature: 1303, Score: 0.00000000
# Feature: 1304, Score: 0.00000000
# Feature: 1305, Score: 0.00000000
# Feature: 1306, Score: 0.00000000
# Feature: 1307, Score: 0.00000000
# Feature: 1308, Score: 0.00000000
# Feature: 1309, Score: 0.00000000
# Feature: 1310, Score: 0.00000000
# Feature: 1311, Score: 0.00000000
# Feature: 1312, Score: 0.00000000
# Feature: 1313, Score: 0.00000000
# Feature: 1314, Score: 0.00000000
# Feature: 1315, Score: 0.00000000
# Feature: 1316, Score: 0.00000000
# Feature: 1317, Score: 0.00000000
# Feature: 1318, Score: 0.00000000
# Feature: 1319, Score: 0.00000000
# Feature: 1320, Score: 0.00000000
# Feature: 1321, Score: 0.00000000
# Feature: 1322, Score: 0.00000000
# Feature: 1323, Score: 0.00000000
# Feature: 1324, Score: 0.00000000
# Feature: 1325, Score: 0.00000000
# Feature: 1326, Score: 0.00000000
# Feature: 1327, Score: 0.00000000
# Feature: 1328, Score: 0.00000000
# Feature: 1329, Score: 0.00000000
# Feature: 1330, Score: 0.00000000
# Feature: 1331, Score: 0.00000000
# Feature: 1332, Score: 0.00000000
# Feature: 1333, Score: 0.00000000
# Feature: 1334, Score: 0.00000000
# Feature: 1335, Score: 0.00000000
# Feature: 1336, Score: 0.00000000
# Feature: 1337, Score: 0.00000000
# Feature: 1338, Score: 0.00000000
# Feature: 1339, Score: 0.00000000
# Feature: 1340, Score: 0.00000000
# Feature: 1341, Score: 0.00000000
# Feature: 1342, Score: 0.00000000
# Feature: 1343, Score: 0.00000000
# Feature: 1344, Score: 0.00000000
# Feature: 1345, Score: 0.00000000
# Feature: 1346, Score: 0.00000000
# Feature: 1347, Score: 0.00000000
# Feature: 1348, Score: 0.00000000
# Feature: 1349, Score: 0.00000000
# Feature: 1350, Score: 0.00000000
# Feature: 1351, Score: 0.00000000
# Feature: 1352, Score: 0.00000000
# Feature: 1353, Score: 0.00000000
# Feature: 1354, Score: 0.00000000
# Feature: 1355, Score: 0.00000000
# Feature: 1356, Score: 0.00000000
# Feature: 1357, Score: 0.00000000
# Feature: 1358, Score: 0.00000000
# Feature: 1359, Score: 0.00000000
# Feature: 1360, Score: 0.00000000
# Feature: 1361, Score: 0.00000000
# Feature: 1362, Score: 0.00000000
# Feature: 1363, Score: 0.00000000
# Feature: 1364, Score: 0.00000000
# Feature: 1365, Score: 0.00000000
# Feature: 1366, Score: 0.00000000
# Feature: 1367, Score: 0.00000000
# Feature: 1368, Score: 0.00000000
# Feature: 1369, Score: 0.00000000
# Feature: 1370, Score: 0.00000000
# Feature: 1371, Score: 0.00000000
# Feature: 1372, Score: 0.00000000
# Feature: 1373, Score: 0.00000000
# Feature: 1374, Score: 0.00000000
# Feature: 1375, Score: 0.00000000
# Feature: 1376, Score: 0.00000000
# Feature: 1377, Score: 0.00000000
# Feature: 1378, Score: 0.00000000
# Feature: 1379, Score: 0.00000000
# Feature: 1380, Score: 0.00000000
# Feature: 1381, Score: 0.00000000
# Feature: 1382, Score: 0.00000000
# Feature: 1383, Score: 0.00000000
# Feature: 1384, Score: 0.00000000
# Feature: 1385, Score: 0.00000000
# Feature: 1386, Score: 0.00000000
# Feature: 1387, Score: 0.00000000
# Feature: 1388, Score: 0.00000000
# Feature: 1389, Score: 0.00000000
# Feature: 1390, Score: 0.00000000
# Feature: 1391, Score: 0.00000000
# Feature: 1392, Score: 0.00000000
# Feature: 1393, Score: 0.00000000
# Feature: 1394, Score: 0.00000000
# Feature: 1395, Score: 0.00000000
# Feature: 1396, Score: 0.00000000
# Feature: 1397, Score: 0.00000000
# Feature: 1398, Score: 0.00000000
# Feature: 1399, Score: 0.00000000
# Feature: 1400, Score: 0.00000000
# Feature: 1401, Score: 0.00000000
# Feature: 1402, Score: 0.00000000
# Feature: 1403, Score: 0.00000000
# Feature: 1404, Score: 0.00000000
# Feature: 1405, Score: 0.00000000
# Feature: 1406, Score: 0.00000000
# Feature: 1407, Score: 0.00000000
# Feature: 1408, Score: 0.00000000
# Feature: 1409, Score: 0.00000000
# Feature: 1410, Score: 0.00000000
# Feature: 1411, Score: 0.00000000
# Feature: 1412, Score: 0.00000000
# Feature: 1413, Score: 0.00000000
# Feature: 1414, Score: 0.00000000
# Feature: 1415, Score: 0.00000000
# Feature: 1416, Score: 0.00000000
# Feature: 1417, Score: 0.00000000
# Feature: 1418, Score: 0.00000000
# Feature: 1419, Score: 0.00000000
# Feature: 1420, Score: 0.00000000
# Feature: 1421, Score: 0.00000000
# Feature: 1422, Score: 0.00000000
# Feature: 1423, Score: 0.00000000
# Feature: 1424, Score: 0.00000000
# Feature: 1425, Score: 0.00000000
# Feature: 1426, Score: 0.00000000
# Feature: 1427, Score: 0.00000000
# Feature: 1428, Score: 0.00000000
# Feature: 1429, Score: 0.00000000
# Feature: 1430, Score: 0.00000000
# Feature: 1431, Score: 0.00000000
# Feature: 1432, Score: 0.00000000
# Feature: 1433, Score: 0.00000000
# Feature: 1434, Score: 0.00000000
# Feature: 1435, Score: 0.00000000
# Feature: 1436, Score: 0.00000000
# Feature: 1437, Score: 0.00000000
# Feature: 1438, Score: 0.00000000
# Feature: 1439, Score: 0.00000000
# Feature: 1440, Score: 0.00000000
# Feature: 1441, Score: 0.00000000
# Feature: 1442, Score: 0.00000000
# Feature: 1443, Score: 0.00000000
# Feature: 1444, Score: 0.00000000
# Feature: 1445, Score: 0.00000000
# Feature: 1446, Score: 0.00000000
# Feature: 1447, Score: 0.00000000
# Feature: 1448, Score: 0.00000000
# Feature: 1449, Score: 0.00000000
# Feature: 1450, Score: 0.00000000
# Feature: 1451, Score: 0.00000000
# Feature: 1452, Score: 0.00000000
# Feature: 1453, Score: 0.00000000
# Feature: 1454, Score: 0.00000000
# Feature: 1455, Score: 0.00000000
# Feature: 1456, Score: 0.00000000
# Feature: 1457, Score: 0.00000000
# Feature: 1458, Score: 0.00000000
# Feature: 1459, Score: 0.00000000
# Feature: 1460, Score: 0.00000000
# Feature: 1461, Score: 0.00000000
# Feature: 1462, Score: 0.00000000
# Feature: 1463, Score: 0.00000000
# Feature: 1464, Score: 0.00000000
# Feature: 1465, Score: 0.00000000
# Feature: 1466, Score: 0.00000000
# Feature: 1467, Score: 0.00000000
# Feature: 1468, Score: 0.00000000
# Feature: 1469, Score: 0.00000000
# Feature: 1470, Score: 0.00000000
# Feature: 1471, Score: 0.00000000
# Feature: 1472, Score: 0.00000000
# Feature: 1473, Score: 0.00000000
# Feature: 1474, Score: 0.00000000
# Feature: 1475, Score: 0.00000000
# Feature: 1476, Score: 0.00000000
# Feature: 1477, Score: 0.00000000
# Feature: 1478, Score: 0.00000000
# Feature: 1479, Score: 0.00000000
# Feature: 1480, Score: 0.00000000
# Feature: 1481, Score: 0.00000000
# Feature: 1482, Score: 0.00000000
# Feature: 1483, Score: 0.00000000
# Feature: 1484, Score: 0.00000000
# Feature: 1485, Score: 0.00000000
# Feature: 1486, Score: 0.00000000
# ...
# Feature: 2852, Score: 0.00000000
# Feature: 2853, Score: 0.00000000
# Feature: 2854, Score: 0.00000000
# Feature: 2855, Score: 0.00000000
# Feature: 2856, Score: 0.00000000
# Feature: 2857, Score: 0.00000000
# Feature: 2858, Score: 0.00000000
# Feature: 2859, Score: 0.00000000
# Feature: 2860, Score: 0.00000000
# Feature: 2861, Score: 0.00000000
# Feature: 2862, Score: 0.00000000
# Feature: 2863, Score: 0.00000000
# Feature: 2864, Score: 0.00000000
# Feature: 2865, Score: 0.00000000
# Feature: 2866, Score: 0.00000000
# Feature: 2867, Score: 0.00000000
# Feature: 2868, Score: 0.00000000
# Feature: 2869, Score: 0.00000000
# Feature: 2870, Score: 0.00000000
# Feature: 2871, Score: 0.00000000
# Feature: 2872, Score: 0.00000000
# Feature: 2873, Score: 0.00000000
# Feature: 2874, Score: 0.00000000
# Feature: 2875, Score: 0.00000000
# Feature: 2876, Score: 0.00000000
# Feature: 2877, Score: 0.00000000
# Feature: 2878, Score: 0.00000000
# Feature: 2879, Score: 0.00000000
# Feature: 2880, Score: 0.00000000
# Feature: 2881, Score: 0.00000000
# Feature: 2882, Score: 0.00000000
# Feature: 2883, Score: 0.00000000
# Feature: 2884, Score: 0.00000000
# Feature: 2885, Score: 0.00000000
# Feature: 2886, Score: 0.00000000
# Feature: 2887, Score: 0.00000000
# Feature: 2888, Score: 0.00000000
# Feature: 2889, Score: 0.00000000
# Feature: 2890, Score: 0.00000000
# Feature: 2891, Score: 0.00000000
# Feature: 2892, Score: 0.00000000
# Feature: 2893, Score: 0.00000000
# Feature: 2894, Score: 0.00000000
# Feature: 2895, Score: 0.00000000
# Feature: 2896, Score: 0.00000000
# Feature: 2897, Score: 0.00000000
# Feature: 2898, Score: 0.00000000
# Feature: 2899, Score: 0.00000000
# Feature: 2900, Score: 0.00000000
# Feature: 2901, Score: 0.00000000
# Feature: 2902, Score: 0.00000000
# Feature: 2903, Score: 0.00000000
# Feature: 2904, Score: 0.00000000
# Feature: 2905, Score: 0.00000000
# Feature: 2906, Score: 0.00000000
# Feature: 2907, Score: 0.00000000
# Feature: 2908, Score: 0.00000000
# Feature: 2909, Score: 0.00000000
# Feature: 2910, Score: 0.00000000
# Feature: 2911, Score: 0.00000000
# Feature: 2912, Score: 0.00000000
# Feature: 2913, Score: 0.00000000
# Feature: 2914, Score: 0.00000000
# Feature: 2915, Score: 0.00000000
# Feature: 2916, Score: 0.00000000
# Feature: 2917, Score: 0.00000000
# Feature: 2918, Score: 0.00000000
# Feature: 2919, Score: 0.00000000
# Feature: 2920, Score: 0.00000000
# Feature: 2921, Score: 0.00000000
# Feature: 2922, Score: 0.00000000
# Feature: 2923, Score: 0.00000000
# Feature: 2924, Score: 0.00000000
# Feature: 2925, Score: 0.00000000
# Feature: 2926, Score: 0.00000000
# Feature: 2927, Score: 0.00000000
# Feature: 2928, Score: 0.00000000
# Feature: 2929, Score: 0.00000000
# Feature: 2930, Score: 0.00000000
# Feature: 2931, Score: 0.00000000
# Feature: 2932, Score: 0.00000000
# Feature: 2933, Score: 0.00000000
# Feature: 2934, Score: 0.00000000
# Feature: 2935, Score: 0.00000000
# Feature: 2936, Score: 0.00000000
# Feature: 2937, Score: 0.00000000
# Feature: 2938, Score: 0.00000000
# Feature: 2939, Score: 0.00000000
# Feature: 2940, Score: 0.00000000
# Feature: 2941, Score: 0.00000000
# Feature: 2942, Score: 0.00000000
# Feature: 2943, Score: 0.00000000
# Feature: 2944, Score: 0.00000000
# Feature: 2945, Score: 0.00000000
# Feature: 2946, Score: 0.00000000
# Feature: 2947, Score: 0.00000000
# Feature: 2948, Score: 0.00000000
# Feature: 2949, Score: 0.00000000
# Feature: 2950, Score: 0.00000000
# Feature: 2951, Score: 0.00000000
# Feature: 2952, Score: 0.00000000
# Feature: 2953, Score: 0.00000000
# Feature: 2954, Score: 0.00000000
# Feature: 2955, Score: 0.00000000
# Feature: 2956, Score: 0.00000000
# Feature: 2957, Score: 0.00000000
# Feature: 2958, Score: 0.00000000
# Feature: 2959, Score: 0.00000000
# Feature: 2960, Score: 0.00000000
# Feature: 2961, Score: 0.00000000
# Feature: 2962, Score: 0.00000000
# Feature: 2963, Score: 0.00000000
# Feature: 2964, Score: 0.00000000
# Feature: 2965, Score: 0.00000000
# Feature: 2966, Score: 0.00000000
# Feature: 2967, Score: 0.00000000
# Feature: 2968, Score: 0.00000000
# Feature: 2969, Score: 0.00000000
# Feature: 2970, Score: 0.00000000
# Feature: 2971, Score: 0.00000000
# Feature: 2972, Score: 0.00000000
# Feature: 2973, Score: 0.00000000
# Feature: 2974, Score: 0.00000000
# Feature: 2975, Score: 0.00000000
# Feature: 2976, Score: 0.00000000
# Feature: 2977, Score: 0.00000000
# Feature: 2978, Score: 0.00000000
# Feature: 2979, Score: 0.00000000
# Feature: 2980, Score: 0.00000000
# Feature: 2981, Score: 0.00000000
# Feature: 2982, Score: 0.00000000
# Feature: 2983, Score: 0.00000000
# Feature: 2984, Score: 0.00000000
# Feature: 2985, Score: 0.00000000
# Feature: 2986, Score: 0.00000000
# Feature: 2987, Score: 0.00000000
# Feature: 2988, Score: 0.00000000
# Feature: 2989, Score: 0.00000000
# Feature: 2990, Score: 0.00000000
# Feature: 2991, Score: 0.00000000
# Feature: 2992, Score: 0.00000000
# Feature: 2993, Score: 0.00000000
# Feature: 2994, Score: 0.00000000
# Feature: 2995, Score: 0.00000000
# Feature: 2996, Score: 0.00000000
# Feature: 2997, Score: 0.00000000
# Feature: 2998, Score: 0.00000000
# Feature: 2999, Score: 0.00000000
# Feature: 3000, Score: 0.00000000
# Feature: 3001, Score: 0.00000000
# Feature: 3002, Score: 0.00000000
# Feature: 3003, Score: 0.00000000
# Feature: 3004, Score: 0.00000000
# Feature: 3005, Score: 0.00000000
# Feature: 3006, Score: 0.00000000
# Feature: 3007, Score: 0.00000000
# Feature: 3008, Score: 0.00000000
# Feature: 3009, Score: 0.00000000
# Feature: 3010, Score: 0.00000000
# Feature: 3011, Score: 0.00000000
# Feature: 3012, Score: 0.00000000
# Feature: 3013, Score: 0.00000000
# Feature: 3014, Score: 0.00000000
# Feature: 3015, Score: 0.00000000
# Feature: 3016, Score: 0.00000000
# Feature: 3017, Score: 0.00000000
# Feature: 3018, Score: 0.00000000
# Feature: 3019, Score: 0.00000000
# Feature: 3020, Score: 0.00000000
# Feature: 3021, Score: 0.00000000
# Feature: 3022, Score: 0.00000000
# Feature: 3023, Score: 0.00000000
# Feature: 3024, Score: 0.00000000
# Feature: 3025, Score: 0.00000000
# Feature: 3026, Score: 0.00000000
# Feature: 3027, Score: 0.00000000
# Feature: 3028, Score: 0.00000000
# Feature: 3029, Score: 0.00000000
# Feature: 3030, Score: 0.00000000
# Feature: 3031, Score: 0.00000000
# Feature: 3032, Score: 0.00000000
# Feature: 3033, Score: 0.00000000
# Feature: 3034, Score: 0.00000000
# Feature: 3035, Score: 0.00000000
# Feature: 3036, Score: 0.00000000
# Feature: 3037, Score: 0.00000000
# Feature: 3038, Score: 0.00000000
# Feature: 3039, Score: 0.00000000
# Feature: 3040, Score: 0.00000000
# Feature: 3041, Score: 0.00000000
# Feature: 3042, Score: 0.00000000
# Feature: 3043, Score: 0.00000000
# Feature: 3044, Score: 0.00000000
# Feature: 3045, Score: 0.00000000
# Feature: 3046, Score: 0.00000000
# Feature: 3047, Score: 0.00000000
# Feature: 3048, Score: 0.00000000
# Feature: 3049, Score: 0.00000000
# Feature: 3050, Score: 0.00000000
# Feature: 3051, Score: 0.00000000
# Feature: 3052, Score: 0.00000000
# Feature: 3053, Score: 0.00000000
# Feature: 3054, Score: 0.00000000
# Feature: 3055, Score: 0.00000000
# Feature: 3056, Score: 0.00000000
# Feature: 3057, Score: 0.00000000
# Feature: 3058, Score: 0.00000000
# Feature: 3059, Score: 0.00000000
# Feature: 3060, Score: 0.00000000
# Feature: 3061, Score: 0.00000000
# Feature: 3062, Score: 0.00000000
# Feature: 3063, Score: 0.00000000
# Feature: 3064, Score: 0.00000000
# Feature: 3065, Score: 0.00000000
# Feature: 3066, Score: 0.00000000
# Feature: 3067, Score: 0.00000000
# Feature: 3068, Score: 0.00000000
# Feature: 3069, Score: 0.00000000
# Feature: 3070, Score: 0.00000000
# Feature: 3071, Score: 0.00000000
# Feature: 3072, Score: 0.00000000
# Feature: 3073, Score: 0.00000000
# Feature: 3074, Score: 0.00000000
# Feature: 3075, Score: 0.00000000
# Feature: 3076, Score: 0.00000000
# Feature: 3077, Score: 0.00000000
# Feature: 3078, Score: 0.00000000
# Feature: 3079, Score: 0.00000000
# Feature: 3080, Score: 0.00000000
# Feature: 3081, Score: 0.00000000
# Feature: 3082, Score: 0.00000000
# Feature: 3083, Score: 0.00000000
# Feature: 3084, Score: 0.00000000
# Feature: 3085, Score: 0.00000000
# Feature: 3086, Score: 0.00000000
# Feature: 3087, Score: 0.00000000
# Feature: 3088, Score: 0.00000000
# Feature: 3089, Score: 0.00000000
# Feature: 3090, Score: 0.00000000
# Feature: 3091, Score: 0.00000000
# Feature: 3092, Score: 0.00000000
# Feature: 3093, Score: 0.00000000
# Feature: 3094, Score: 0.00000000
# Feature: 3095, Score: 0.00000000
# Feature: 3096, Score: 0.00000000
# Feature: 3097, Score: 0.00000000
# Feature: 3098, Score: 0.00000000
# Feature: 3099, Score: 0.00000000
# Feature: 3100, Score: 0.00000000
# Feature: 3101, Score: 0.00000000
# Feature: 3102, Score: 0.00000000
# Feature: 3103, Score: 0.00000000
# Feature: 3104, Score: 0.00000000
# Feature: 3105, Score: 0.00000000
# Feature: 3106, Score: 0.00000000
# Feature: 3107, Score: 0.00000000
# Feature: 3108, Score: 0.00000000
# Feature: 3109, Score: 0.00000000
# Feature: 3110, Score: 0.00000000
# Feature: 3111, Score: 0.00000000
# Feature: 3112, Score: 0.00000000
# Feature: 3113, Score: 0.00000000
# Feature: 3114, Score: 0.00000000
# Feature: 3115, Score: 0.00000000
# Feature: 3116, Score: 0.00000000
# Feature: 3117, Score: 0.00000000
# Feature: 3118, Score: 0.00000000
# Feature: 3119, Score: 0.00000000
# Feature: 3120, Score: 0.00000000
# Feature: 3121, Score: 0.00000000
# Feature: 3122, Score: 0.00000000
# Feature: 3123, Score: 0.00000000
# Feature: 3124, Score: 0.00000000
# Feature: 3125, Score: 0.00000000
# Feature: 3126, Score: 0.00000000
# Feature: 3127, Score: 0.00000000
# Feature: 3128, Score: 0.00000000
# Feature: 3129, Score: 0.00000000
# Feature: 3130, Score: 0.00000000
# Feature: 3131, Score: 0.00000000
# Feature: 3132, Score: 0.00000000
# Feature: 3133, Score: 0.00000000
# Feature: 3134, Score: 0.00000000
# Feature: 3135, Score: 0.00000000
# Feature: 3136, Score: 0.00000000
# Feature: 3137, Score: 0.00000000
# Feature: 3138, Score: 0.00000000
# Feature: 3139, Score: 0.00000000
# Feature: 3140, Score: 0.00000000
# Feature: 3141, Score: 0.00000000
# Feature: 3142, Score: 0.00000000
# Feature: 3143, Score: 0.00000000
# Feature: 3144, Score: 0.00000000
# Feature: 3145, Score: 0.00000000
# Feature: 3146, Score: 0.00000000
# Feature: 3147, Score: 0.00000000
# Feature: 3148, Score: 0.00000000
# Feature: 3149, Score: 0.00000000
# Feature: 3150, Score: 0.00000000
# Feature: 3151, Score: 0.00000000
# Feature: 3152, Score: 0.00000000
# Feature: 3153, Score: 0.00000000
# Feature: 3154, Score: 0.00000000
# Feature: 3155, Score: 0.00000000
# Feature: 3156, Score: 0.00000000
# Feature: 3157, Score: 0.00000000
# Feature: 3158, Score: 0.00000000
# Feature: 3159, Score: 0.00000000
# Feature: 3160, Score: 0.00000000
# Feature: 3161, Score: 0.00000000
# Feature: 3162, Score: 0.00000000
# Feature: 3163, Score: 0.00000000
# Feature: 3164, Score: 0.00000000
# Feature: 3165, Score: 0.00000000
# Feature: 3166, Score: 0.00000000
# Feature: 3167, Score: 0.00000000
# Feature: 3168, Score: 0.00000000
# Feature: 3169, Score: 0.00000000
# Feature: 3170, Score: 0.00000000
# Feature: 3171, Score: 0.00000000
# Feature: 3172, Score: 0.00000000
# Feature: 3173, Score: 0.00000000
# Feature: 3174, Score: 0.00000000
# Feature: 3175, Score: 0.00000000
# Feature: 3176, Score: 0.00000000
# Feature: 3177, Score: 0.00000000
# Feature: 3178, Score: 0.00000000
# Feature: 3179, Score: 0.00000000
# Feature: 3180, Score: 0.00000000
# Feature: 3181, Score: 0.00000000
# Feature: 3182, Score: 0.00000000
# Feature: 3183, Score: 0.00000000
# Feature: 3184, Score: 0.00000000
# Feature: 3185, Score: 0.00000000
# Feature: 3186, Score: 0.00000000
# Feature: 3187, Score: 0.00000000
# Feature: 3188, Score: 0.00000000
# Feature: 3189, Score: 0.00000000
# Feature: 3190, Score: 0.00000000
# Feature: 3191, Score: 0.00000000
# Feature: 3192, Score: 0.00000000
# Feature: 3193, Score: 0.00000000
# Feature: 3194, Score: 0.00000000
# Feature: 3195, Score: 0.00000000
# Feature: 3196, Score: 0.00000000
# Feature: 3197, Score: 0.00000000
# Feature: 3198, Score: 0.00000000
# Feature: 3199, Score: 0.00000000
# Feature: 3200, Score: 0.00000000
# Feature: 3201, Score: 0.00000000
# Feature: 3202, Score: 0.00000000
# Feature: 3203, Score: 0.00000000
# Feature: 3204, Score: 0.00000000
# Feature: 3205, Score: 0.00000000
# Feature: 3206, Score: 0.00000000
# Feature: 3207, Score: 0.00000000
# Feature: 3208, Score: 0.00000000
# Feature: 3209, Score: 0.00000000
# Feature: 3210, Score: 0.00000000
# Feature: 3211, Score: 0.00000000
# Feature: 3212, Score: 0.00000000
# Feature: 3213, Score: 0.00000000
# Feature: 3214, Score: 0.00000000
# Feature: 3215, Score: 0.00000000
# Feature: 3216, Score: 0.00000000
# Feature: 3217, Score: 0.00000000
# Feature: 3218, Score: 0.00000000
# Feature: 3219, Score: 0.00000000
# Feature: 3220, Score: 0.00000000
# Feature: 3221, Score: 0.00000000
# Feature: 3222, Score: 0.00000000
# Feature: 3223, Score: 0.00000000
# Feature: 3224, Score: 0.00000000
# Feature: 3225, Score: 0.00000000
# Feature: 3226, Score: 0.00000000
# Feature: 3227, Score: 0.00000000
# Feature: 3228, Score: 0.00000000
# Feature: 3229, Score: 0.00000000
# Feature: 3230, Score: 0.00000000
# Feature: 3231, Score: 0.00000000
# Feature: 3232, Score: 0.00000000
# Feature: 3233, Score: 0.00000000
# Feature: 3234, Score: 0.00000000
# Feature: 3235, Score: 0.00000000
# Feature: 3236, Score: 0.00000000
# Feature: 3237, Score: 0.00000000
# Feature: 3238, Score: 0.00000000
# Feature: 3239, Score: 0.00000000
# Feature: 3240, Score: 0.00000000
# Feature: 3241, Score: 0.00000000
# Feature: 3242, Score: 0.00000000
# Feature: 3243, Score: 0.00000000
# Feature: 3244, Score: 0.00000000
# Feature: 3245, Score: 0.00000000
# Feature: 3246, Score: 0.00000000
# Feature: 3247, Score: 0.00000000
# Feature: 3248, Score: 0.00000000
# Feature: 3249, Score: 0.00000000
# Feature: 3250, Score: 0.00000000
# Feature: 3251, Score: 0.00000000
# Feature: 3252, Score: 0.00000000
# Feature: 3253, Score: 0.00000000
# Feature: 3254, Score: 0.00000000
# Feature: 3255, Score: 0.00000000
# Feature: 3256, Score: 0.00000000
# Feature: 3257, Score: 0.00000000
# Feature: 3258, Score: 0.00000000
# Feature: 3259, Score: 0.00000000
# Feature: 3260, Score: 0.00000000
# Feature: 3261, Score: 0.00000000
# Feature: 3262, Score: 0.00000000
# Feature: 3263, Score: 0.00000000
# Feature: 3264, Score: 0.00000000
# Feature: 3265, Score: 0.00000000
# Feature: 3266, Score: 0.00000000
# Feature: 3267, Score: 0.00000000
# Feature: 3268, Score: 0.00000000
# Feature: 3269, Score: 0.00000000
# Feature: 3270, Score: 0.00000000
# Feature: 3271, Score: 0.00000000
# Feature: 3272, Score: 0.00000000
# Feature: 3273, Score: 0.00000000
# Feature: 3274, Score: 0.00000000
# Feature: 3275, Score: 0.00000000
# Feature: 3276, Score: 0.00000000
# Feature: 3277, Score: 0.00000000
# Feature: 3278, Score: 0.00000000
# Feature: 3279, Score: 0.00000000
# Feature: 3280, Score: 0.00000000
# Feature: 3281, Score: 0.00000000
# Feature: 3282, Score: 0.00000000
# Feature: 3283, Score: 0.00000000
# Feature: 3284, Score: 0.00000000
# Feature: 3285, Score: 0.00000000
# Feature: 3286, Score: 0.00000000
# Feature: 3287, Score: 0.00000000
# Feature: 3288, Score: 0.00000000
# Feature: 3289, Score: 0.00000000
# Feature: 3290, Score: 0.00000000
# Feature: 3291, Score: 0.00000000
# Feature: 3292, Score: 0.00000000
# Feature: 3293, Score: 0.00000000
# Feature: 3294, Score: 0.00000000
# Feature: 3295, Score: 0.00000000
# Feature: 3296, Score: 0.00000000
# Feature: 3297, Score: 0.00000000
# Feature: 3298, Score: 0.00000000
# Feature: 3299, Score: 0.00000000
# Feature: 3300, Score: 0.00000000
# Feature: 3301, Score: 0.00000000
# Feature: 3302, Score: 0.00000000
# Feature: 3303, Score: 0.00000000
# Feature: 3304, Score: 0.00000000
# Feature: 3305, Score: 0.00000000
# Feature: 3306, Score: 0.00000000
# Feature: 3307, Score: 0.00000000
# Feature: 3308, Score: 0.00000000
# Feature: 3309, Score: 0.00000000
# Feature: 3310, Score: 0.00000000
# Feature: 3311, Score: 0.00000000
# Feature: 3312, Score: 0.00000000
# Feature: 3313, Score: 0.00000000
# Feature: 3314, Score: 0.00000000
# Feature: 3315, Score: 0.00000000
# Feature: 3316, Score: 0.00000000
# Feature: 3317, Score: 0.00000000
# Feature: 3318, Score: 0.00000000
# Feature: 3319, Score: 0.00000000
# Feature: 3320, Score: 0.00000000
# Feature: 3321, Score: 0.00000000
# Feature: 3322, Score: 0.00000000
# Feature: 3323, Score: 0.00000000
# Feature: 3324, Score: 0.00000000
# Feature: 3325, Score: 0.00000000
# Feature: 3326, Score: 0.00000000
# Feature: 3327, Score: 0.00000000
# Feature: 3328, Score: 0.00000000
# Feature: 3329, Score: 0.00000000
# Feature: 3330, Score: 0.00000000
# Feature: 3331, Score: 0.00000000
# Feature: 3332, Score: 0.00000000
# Feature: 3333, Score: 0.00000000
# Feature: 3334, Score: 0.00000000
# Feature: 3335, Score: 0.00000000

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import graphviz
import pickle
import joblib
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, cross_val_score, cross_validate
from tensorflow.python.keras.utils import np_utils
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.tree import export_graphviz
from sklearn.metrics import accuracy_score, confusion_matrix

#데이터 입력
df = pd.read_csv('./VRK2_inhibitor_descriptor_Internal_dataset_edit1.csv')

#데이터 분류
dataset = df.values
X = dataset[:,0:-1]#.astype(float)
Y = dataset[:,-1]#.astype(int)

#X 표준화

scaler =StandardScaler()

scaler.fit(X)
X_scaled = scaler.transform(X)

#데이터셋 분리
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y, test_size=0.2, random_state=10)

#DecisionTree Classifier 생성
dt_clf = DecisionTreeClassifier(max_depth=2, max_features=3, max_leaf_nodes=3, min_samples_leaf=1, 
                                min_samples_split=2, random_state=10)
dt_clf.fit(X_scaled, Y)
pred = dt_clf.predict(X_scaled)
accuracy = accuracy_score(Y, pred)

print('Decision Tree 예측 정확도 : {0:.4f}'.format(accuracy))

#cross val 실행
scores = cross_val_score(dt_clf,X_scaled, Y, scoring='accuracy', cv=5)
print('교차 검증별 정확도:' ,np.round(scores,5))
print('평균 검증 정확도:', np.round(np.mean(scores),5))

#confusion matrix 실행
conf_matrix = confusion_matrix(Y, pred)
print(conf_matrix)

#외부 데이터세트로 실행
ex = pd.read_csv('./VRK2_inhibitor_descriptor_external_dataset_edit1.csv')

datasetex = ex.values
exX = datasetex[:,0:-1]#.astype(float)
exY = datasetex[:,-1]#.astype(int)

#X 표준화

scaler1 =StandardScaler()

scaler1.fit(exX)
exX_scaled = scaler1.transform(exX)

expred = dt_clf.predict(exX_scaled)
accuracy = accuracy_score(exY, expred)

print('Decision Tree 외부세트 예측 정확도 : {0:.4f}'.format(accuracy))

#confusion matrix 실행
ex_conf_matrix = confusion_matrix(exY, expred)
print(ex_conf_matrix)


#전체 데이터셋에 적용

total = pd.read_csv('./VRK2_inhibitor_descriptor_decisionforest_dataset.csv')

dataset_tot = total.values
tot_X = dataset_tot[:,0:-1]#.astype(float)
tot_Y = dataset_tot[:,-1]#.astype(int)

#X 표준화

scaler2 =StandardScaler()

scaler2.fit(tot_X)
tot_X_scaled = scaler2.transform(tot_X)

tot_pred = dt_clf.predict(tot_X_scaled)
accuracy = accuracy_score(tot_Y, tot_pred)

print('Decision Tree 전체세트 예측 정확도 : {0:.4f}'.format(accuracy))

#confusion matrix 실행
conf_matrix_tot = confusion_matrix(tot_Y, tot_pred)
print(conf_matrix_tot)

#시각화
fig, ax = plt.subplots(nrows = 1, ncols = 3, figsize=(16, 5))
sns.heatmap(conf_matrix/26, annot=True, ax=ax[0])
ax[0].set_title('Internal confusion matrix', pad = 12)
sns.heatmap(ex_conf_matrix/6, annot=True, ax=ax[1])
ax[1].set_title('External confusion matrix', pad = 12)
sns.heatmap(conf_matrix_tot/32, annot=True, ax=ax[2])
ax[2].set_title('Total confusion matrix', pad = 12)

#모델 저장
saved_model = joblib.dump(dt_clf,'./VRK2_DecisionTree.pkl')
# Out:
# Decision Tree 예측 정확도 : 0.9231
# 교차 검증별 정확도: [0.83333 1.      1.      0.8     0.4    ]
# 평균 검증 정확도: 0.80667
# [[ 6  0  0  0]
#  [ 2  0  0  0]
#  [ 0  0  8  0]
#  [ 0  0  0 10]]
# Decision Tree 외부세트 예측 정확도 : 0.8333
# [[1 0 0 0]
#  [1 0 0 0]
#  [0 0 2 0]
#  [0 0 0 2]]
# Decision Tree 전체세트 예측 정확도 : 0.9062
# [[ 7  0  0  0]
#  [ 3  0  0  0]
#  [ 0  0 10  0]
#  [ 0  0  0 12]]
# C:\Users\eunwoo\.conda\envs\Tensorflow\lib\site-packages\sklearn\model_selection\_split.py:670: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"
